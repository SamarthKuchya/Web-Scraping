# %%
import bs4
import requests

# %%
search_list=['arm-chair','bean-bags','bench','book-cases',
             'chest-drawers','coffee-table','dining-set',
             'garden-seating','king-beds','queen-beds',
             'two-seater-sofa']

# %%
url='https://www.pepperfry.com/site_product/search?q=book-cases'
headers = {'User-Agent': 'Mozilla/7.0' }

# %%
response=requests.get(url,headers=headers)

# %%
response.content
# Out:
# b'<!DOCTYPE html><html lang="en"><head>\n  <meta charset="utf-8">\n  <meta http-equiv="\xe2\x80\x9dCache-Control\xe2\x80\x9d" content="\xe2\x80\x9dno-cache,no-store,must-revalidate\xe2\x80\x9d">\n  <meta http-equiv="\xe2\x80\x9dPragma\xe2\x80\x9d" content="\xe2\x80\x9dno-cache\xe2\x80\x9d">\n  <meta http-equiv="\xe2\x80\x9dExpires\xe2\x80\x9d" content="\xe2\x80\x9d0&quot;">\n  <meta name="robots" content="noodp, noydir">\n  <title>Online Furniture Shopping Store: Shop Online in India for Furniture, Home Decor, Homeware Products @ Pepperfry\n  </title>\n  <base href="/">\n  <meta name="viewport" content="user-scalable=no, width=device-width, initial-scale=1, maximum-scale=1">\n  <link rel="icon" type="image/x-icon" href="favicon.ico">\n  <!-- <script src="https://js.appboycdn.com/web-sdk/4.5/service-worker.js"></script> -->\n  <link rel="preconnect" href="https://fonts.googleapis.com">\n  <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin="">\n  <link rel="preconnect"
# ...

# %%
soup=bs4.BeautifulSoup(response.content)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <meta charset="utf-8"/>
# <meta content="”no-cache,no-store,must-revalidate”" http-equiv="”Cache-Control”"/>
# <meta content="”no-cache”" http-equiv="”Pragma”"/>
# <meta content='”0"' http-equiv="”Expires”"/>
# <meta content="noodp, noydir" name="robots"/>
# <title>Online Furniture Shopping Store: Shop Online in India for Furniture, Home Decor, Homeware Products @ Pepperfry
#   </title>
# <base href="/"/>
# <meta content="user-scalable=no, width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <link href="favicon.ico" rel="icon" type="image/x-icon"/>
# <!-- <script src="https://js.appboycdn.com/web-sdk/4.5/service-worker.js"></script> -->
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
# <link crossorigin="" href="https://ii1.pepperfry.com" rel="preconnect"/>
# <link crossorigin="" href="https://ii2.pepperfry.com" rel="preconnect"/>
# ...

# %%
first=soup.find_all('img')[8:]

# %%
for i in range(2000):
    try:
        if(id[i].attrs['a']):
            print(id[i].attrs['a'])
#             count+=1
    except:
        pass

# %%
id=soup.find_all('a')

# %%
id[24:]
# Out:
# [<a _ngcontent-sc167="" class="hd-menu-category-href-item text-sm cursor-pointer" data-id="2 Seater Sofas" href="/category/2-seater-sofas.html?type=hover-furniture-sofas-2seatersofas">2 Seater Sofas </a>,
#  <a _ngcontent-sc167="" class="hd-menu-category-href-item text-sm cursor-pointer" data-id="1 Seater Sofas" href="/category/1-seater-sofas.html?type=hover-furniture-sofas-1seatersofas">1 Seater Sofas </a>,
#  <a _ngcontent-sc167="" class="hd-menu-category-href-item text-sm cursor-pointer" data-id="Sofa Sets" href="/category/sofa-sets.html?type=hover-furniture-sofas-sofasets">Sofa Sets </a>,
#  <a _ngcontent-sc167="" class="hd-menu-category-link" href="/category/sectional-sofas.html?type=hover-furniture-sectionalsofas">Sectional Sofas </a>,
#  <a _ngcontent-sc167="" class="hd-menu-category-href-item text-sm cursor-pointer" data-id="LHS Sectionals" href="/category/lhs-sectional-sofas.html?type=hover-furniture-sectionalsofas-lhssectionals">LHS Sectionals </a>,
# ...

# %%
id[24].attrs['href']
# Out:
# '/category/2-seater-sofas.html?type=hover-furniture-sofas-2seatersofas'

# %%
for i in range(24,32):
    print(id[i].attrs['href'])
# Out:
# /category/2-seater-sofas.html?type=hover-furniture-sofas-2seatersofas
# /category/1-seater-sofas.html?type=hover-furniture-sofas-1seatersofas
# /category/sofa-sets.html?type=hover-furniture-sofas-sofasets
# /category/sectional-sofas.html?type=hover-furniture-sectionalsofas
# /category/lhs-sectional-sofas.html?type=hover-furniture-sectionalsofas-lhssectionals
# /category/rhs-sectional-sofas.html?type=hover-furniture-sectionalsofas-rhssectionals
# /category/corner-sofas.html?type=hover-furniture-sectionalsofas-cornersofas
# /category/sofa-cum-beds.html?type=hover-furniture-sofacumbeds

# %%
product=id[24].attrs['href']

# %%
url=f'https://www.pepperfry.com/{product}'

# %%
url
# Out:
# 'https://www.pepperfry.com//category/2-seater-sofas.html?type=hover-furniture-sofas-2seatersofas'

# %%
response=requests.get(url,headers=headers)

# %%
soup=bs4.BeautifulSoup(response.content)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <meta charset="utf-8"/>
# <meta content="”no-cache,no-store,must-revalidate”" http-equiv="”Cache-Control”"/>
# <meta content="”no-cache”" http-equiv="”Pragma”"/>
# <meta content='”0"' http-equiv="”Expires”"/>
# <meta content="noodp, noydir" name="robots"/>
# <title>Online Furniture Shopping Store: Shop Online in India for Furniture, Home Decor, Homeware Products @ Pepperfry
#   </title>
# <base href="/"/>
# <meta content="user-scalable=no, width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <link href="favicon.ico" rel="icon" type="image/x-icon"/>
# <!-- <script src="https://js.appboycdn.com/web-sdk/4.5/service-worker.js"></script> -->
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
# <link crossorigin="" href="https://ii1.pepperfry.com" rel="preconnect"/>
# <link crossorigin="" href="https://ii2.pepperfry.com" rel="preconnect"/>
# ...

# %%
image=soup.find_all('div')

# %%
image[30].a
# Out:
# <a _ngcontent-sc167="" class="hd-menu-category-link" href="/category/sofas.html?type=hover-furniture-sofas">Sofas </a>

# %%
# scrappy codes for  images

# import scrapy
# url='https://www.pepperfry.com/product/cove-solid-wood-sideboard-in-irish-walnut-colour-2163467.html'
# scrapy shell https://www.pepperfry.com/product/cove-solid-wood-sideboard-in-irish-walnut-colour-2163467.html
# images=response.css('img').getall()[8:17]
# for i in images:
#     start=i.find('src')
#     start+=5
#     end=i.find('jpg')
#     end+=3
#     link=i[start:end]
#     link=link.replace('90x99','1100x1210')

# %%
# product details
# link=url
# product_name=response.css('h1::text').get()
# price=response.css('span::text').getall()[13]
