# %%
import bs4
import requests

# %%
search_list=['arm-chair','bean-bags','bench','book-cases',
             'chest-drawers','coffee-table','dining-set',
             'garden-seating','king-beds','queen-beds',
             'two-seater-sofa']

# %%
url='https://www.pepperfry.com/site_product/search?q=book-cases'
headers = {'User-Agent': 'Mozilla/7.0' }

# %%
response=requests.get(url,headers=headers)

# %%
response.content
# Out:
# b'<!DOCTYPE html><html lang="en"><head>\n  <meta charset="utf-8">\n  <meta http-equiv="\xe2\x80\x9dCache-Control\xe2\x80\x9d" content="\xe2\x80\x9dno-cache,no-store,must-revalidate\xe2\x80\x9d">\n  <meta http-equiv="\xe2\x80\x9dPragma\xe2\x80\x9d" content="\xe2\x80\x9dno-cache\xe2\x80\x9d">\n  <meta http-equiv="\xe2\x80\x9dExpires\xe2\x80\x9d" content="\xe2\x80\x9d0&quot;">\n  <meta name="robots" content="noodp, noydir">\n  <title>Online Furniture Shopping Store: Shop Online in India for Furniture, Home Decor, Homeware Products @ Pepperfry\n  </title>\n  <base href="/">\n  <meta name="viewport" content="user-scalable=no, width=device-width, initial-scale=1, maximum-scale=1">\n  <link rel="icon" type="image/x-icon" href="favicon.ico">\n  <!-- <script src="https://js.appboycdn.com/web-sdk/4.5/service-worker.js"></script> -->\n  <link rel="preconnect" href="https://fonts.googleapis.com">\n  <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin="">\n  <link rel="preconnect" href="https://ii1.pepperfry.com" crossorigin="">\n  <link rel="preconnect" href="https://ii2.pepperfry.com" crossorigin="">\n  <link rel="preconnect" href="https://ii3.pepperfry.com" crossorigin="">\n  <link rel="preconnect" href="https://cw.pepperfry.com" crossorigin="">\n  <!-- Preloading Important Icons -->\n  <link rel="preload" as="image" href="https://ii1.pepperfry.com/assets/w22-pf-logo.svg">\n  <link rel="preload" as="image" href="https://ii2.pepperfry.com/assets/w22-pf-wishlist-icon.svg">\n  <link rel="preload" as="image" href="https://ii1.pepperfry.com/assets/w22-pf-cart-icon.svg">\n  <link rel="preload" as="image" href="https://ii2.pepperfry.com/assets/w22-search-icon.svg">\n  <link rel="preload" as="image" href="https://ii3.pepperfry.com/assets/w38-pf-logo-mobile.svg">\n  <link rel="preload" as="image" href=" https://ii1.pepperfry.com/media/wysiwyg/banners/w23-buy-on-phone-icon-1x.gif"> \n  <link rel="preload" as="image" href="https://ii1.pepperfry.com/assets/w-23-chat-bot.gif"> \n  <meta name="msvalidate.01" content="8C9BCDC3424062BDDA2B4F617B1E81D4">\n  <!-- GA Script for Analytics-->\n  <script type="text/javascript" async="" src="https://cdn.segment.com/analytics.js/v1/bnox7jexPU74jBHFxPWROoNEjczz2XS1/analytics.min.js"></script><script async="true">\n    if (window.innerWidth <= 720) {\n      (function (w, d, s, l, i) {\n        w[l] = w[l] || []; w[l].push({\n          \'gtm.start\':\n            new Date().getTime(), event: \'gtm.js\'\n        }); var f = d.getElementsByTagName(s)[0],\n          j = d.createElement(s), dl = l != \'dataLayer\' ? \'&l=\' + l : \'\'; j.async = true; j.src =\n            \'https://www.googletagmanager.com/gtm.js?id=\' + i + dl; f.parentNode.insertBefore(j, f);\n      })(window, document, \'script\', \'dataLayer\', \'GTM-K8V3Z8\');\n\n    } else {\n\n      (function (w, d, s, l, i) {\n        w[l] = w[l] || []; w[l].push({\n          \'gtm.start\':\n            new Date().getTime(), event: \'gtm.js\'\n        }); var f = d.getElementsByTagName(s)[0],\n          j = d.createElement(s), dl = l != \'dataLayer\' ? \'&l=\' + l : \'\'; j.async = true; j.src =\n            \'https://www.googletagmanager.com/gtm.js?id=\' + i + dl; f.parentNode.insertBefore(j, f);\n      })(window, document, \'script\', \'dataLayer\', \'GTM-TWGMR3\');\n    }\n  </script>\n\n  <!-- Google map dynamic inline script -->\n  <script>\n    (g => { var h, a, k, p = "The Google Maps JavaScript API", c = "google", l = "importLibrary", q = "__ib__", m = document, b = window; b = b[c] || (b[c] = {}); var d = b.maps || (b.maps = {}), r = new Set, e = new URLSearchParams, u = () => h || (h = new Promise(async (f, n) => { await (a = m.createElement("script")); e.set("libraries", [...r] + ""); for (k in g) e.set(k.replace(/[A-Z]/g, t => "_" + t[0].toLowerCase()), g[k]); e.set("callback", c + ".maps." + q); a.src = `https://maps.${c}apis.com/maps/api/js?` + e; d[q] = f; a.onerror = () => h = n(Error(p + " could not load.")); a.nonce = m.query ...

# %%
soup=bs4.BeautifulSoup(response.content)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <meta charset="utf-8"/>
# <meta content="”no-cache,no-store,must-revalidate”" http-equiv="”Cache-Control”"/>
# <meta content="”no-cache”" http-equiv="”Pragma”"/>
# <meta content='”0"' http-equiv="”Expires”"/>
# <meta content="noodp, noydir" name="robots"/>
# <title>Online Furniture Shopping Store: Shop Online in India for Furniture, Home Decor, Homeware Products @ Pepperfry
#   </title>
# <base href="/"/>
# <meta content="user-scalable=no, width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <link href="favicon.ico" rel="icon" type="image/x-icon"/>
# <!-- <script src="https://js.appboycdn.com/web-sdk/4.5/service-worker.js"></script> -->
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
# <link crossorigin="" href="https://ii1.pepperfry.com" rel="preconnect"/>
# <link crossorigin="" href="https://ii2.pepperfry.com" rel="preconnect"/>
# <link crossorigin="" href="https://ii3.pepperfry.com" rel="preconnect"/>
# <link crossorigin="" href="https://cw.pepperfry.com" rel="preconnect"/>
# <!-- Preloading Important Icons -->
# <link as="image" href="https://ii1.pepperfry.com/assets/w22-pf-logo.svg" rel="preload"/>
# <link as="image" href="https://ii2.pepperfry.com/assets/w22-pf-wishlist-icon.svg" rel="preload"/>
# <link as="image" href="https://ii1.pepperfry.com/assets/w22-pf-cart-icon.svg" rel="preload"/>
# <link as="image" href="https://ii2.pepperfry.com/assets/w22-search-icon.svg" rel="preload"/>
# <link as="image" href="https://ii3.pepperfry.com/assets/w38-pf-logo-mobile.svg" rel="preload"/>
# <link as="image" href=" https://ii1.pepperfry.com/media/wysiwyg/banners/w23-buy-on-phone-icon-1x.gif" rel="preload"/>
# <link as="image" href="https://ii1.pepperfry.com/assets/w-23-chat-bot.gif" rel="preload"/>
# <meta content="8C9BCDC3424062BDDA2B4F617B1E81D4" name="msvalidate.01"/>
# <!-- GA Script for Analytics-->
# <script async="" src="https://cdn.segment.com/analytics.js/v1/bnox7jexPU74jBHFxPWROoNEjczz2XS1/analytics.min.js" type="text/javascript"></script><script async="true">
#     if (window.innerWidth <= 720) {
#       (function (w, d, s, l, i) {
#         w[l] = w[l] || []; w[l].push({
#           'gtm.start':
#             new Date().getTime(), event: 'gtm.js'
#         }); var f = d.getElementsByTagName(s)[0],
#           j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#             'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#       })(window, document, 'script', 'dataLayer', 'GTM-K8V3Z8');
#
#     } else {
#
#       (function (w, d, s, l, i) {
#         w[l] = w[l] || []; w[l].push({
#           'gtm.start':
#             new Date().getTime(), event: 'gtm.js'
#         }); var f = d.getElementsByTagName(s)[0],
#           j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#             'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#       })(window, document, 'script', 'dataLayer', 'GTM-TWGMR3');
#     }
#   </script>
# <!-- Google map dynamic inline script -->
# <script>
#     (g => { var h, a, k, p = "The Google Maps JavaScript API", c = "google", l = "importLibrary", q = "__ib__", m = document, b = window; b = b[c] || (b[c] = {}); var d = b.maps || (b.maps = {}), r = new Set, e = new URLSearchParams, u = () => h || (h = new Promise(async (f, n) => { await (a = m.createElement("script")); e.set("libraries", [...r] + ""); for (k in g) e.set(k.replace(/[A-Z]/g, t => "_" + t[0].toLowerCase()), g[k]); e.set("callback", c + ".maps." + q); a.src = `https://maps.${c}apis.com/maps/api/js?` + e; d[q] = f; a.onerror = () => h = n(Error(p + " could not load.")); a.nonce = m.querySelector("script[nonce]")?.nonce || ""; m.head.append(a) })); d[l] ? console.warn(p + " only loads once. Ignoring:", g) : d[l] = (f, ...n) => r.add(f) && u().then(() => d[l](f, ...n)) })({
#       key: "AIzaSyDlKneuC_IiviXS3CMCw7KZhyxsoQc9tRM",
#       v: "quarterly",
#     });
#   </script>
# <!-- Google optimization-->
# <script defer="" src="https://www.googleoptimize.com/optimize.js?id=OPT-PFLLRR3"></script>
# <!-- Bing Script-->
# <script defer="" type="text/javascript">
#     (function (w, d, t, r, u) { var f, n, i; w[u] = w[u] || [], f = function () { var o = { ti: "5153102" }; o.q = w[u], w[u] = new UET(o), w[u].push("pageLoad") }, n = d.createElement(t), n.src = r, n.defer = 1, n.onload = n.onreadystatechange = function () { var s = this.readyState; s && s !== "loaded" && s !== "complete" || (f(), n.onload = n.onreadystatechange = null) }, i = d.getElementsByTagName(t)[0], i.parentNode.insertBefore(n, i) })(window, document, "script", "//bat.bing.com/bat.js", "uetq");
#   </script>
# <!-- <script src="https://cdn.trackjs.com/agent/v3/latest/t.js" crossorigin></script> -->
# <!-- <script defer crossorigin  async="true"
#  src="https://maps.googleapis.com/maps/api/js?v=3.exp&key=AIzaSyDlKneuC_IiviXS3CMCw7KZhyxsoQc9tRM&libraries=places&radius=50">
# </script> -->
# <!-- <script >
#   if (location.host.indexOf("localhost") !== 0) {
#     window.TrackJS && TrackJS.install({
#       token: "6a4e5a0b5e284d5d8332431f7048d8a9",
#       application: "pepperfry-fe-prod",
#     });
#   }
# </script> -->
# <!-- Start VWO Async SmartCode -->
# <link href="https://dev.visualwebsiteoptimizer.com" rel="preconnect"/>
# <script id="vwoCode" type="text/javascript">
# window._vwo_code || (function() {
# var account_id=788314,
# version=2.0,
# settings_tolerance=2000,
# hide_element='body',
# hide_element_style = 'opacity:0 !important;filter:alpha(opacity=0) !important;background:none !important',
# /* DO NOT EDIT BELOW THIS LINE */
# f=false,w=window,d=document,v=d.querySelector('#vwoCode'),cK='_vwo_'+account_id+'_settings',cc={};try{var c=JSON.parse(localStorage.getItem('_vwo_'+account_id+'_config'));cc=c&&typeof c==='object'?c:{}}catch(e){}var stT=cc.stT==='session'?w.sessionStorage:w.localStorage;code={use_existing_jquery:function(){return typeof use_existing_jquery!=='undefined'?use_existing_jquery:undefined},library_tolerance:function(){return typeof library_tolerance!=='undefined'?library_tolerance:undefined},settings_tolerance:function(){return cc.sT||settings_tolerance},hide_element_style:function(){return'{'+(cc.hES||hide_element_style)+'}'},hide_element:function(){return typeof cc.hE==='string'?cc.hE:hide_element},getVersion:function(){return version},finish:function(){if(!f){f=true;var e=d.getElementById('_vis_opt_path_hides');if(e)e.parentNode.removeChild(e)}},finished:function(){return f},load:function(e){var t=this.getSettings(),n=d.createElement('script'),i=this;if(t){n.textContent=t;d.getElementsByTagName('head')[0].appendChild(n);if(!w.VWO||VWO.caE){stT.removeItem(cK);i.load(e)}}else{n.fetchPriority='high';n.src=e;n.type='text/javascript';n.onerror=function(){_vwo_code.finish()};d.getElementsByTagName('head')[0].appendChild(n)}},getSettings:function(){try{var e=stT.getItem(cK);if(!e){return}e=JSON.parse(e);if(Date.now()>e.e){stT.removeItem(cK);return}return e.s}catch(e){return}},init:function(){if(d.URL.indexOf('__vwo_disable__')>-1)return;var e=this.settings_tolerance();w._vwo_settings_timer=setTimeout(function(){_vwo_code.finish();stT.removeItem(cK)},e);var t=d.currentScript,n=d.createElement('style'),i=this.hide_element(),r=t&&!t.async&&i?i+this.hide_element_style():'',c=d.getElementsByTagName('head')[0];n.setAttribute('id','_vis_opt_path_hides');v&&n.setAttribute('nonce',v.nonce);n.setAttribute('type','text/css');if(n.styleSheet)n.styleSheet.cssText=r;else n.appendChild(d.createTextNode(r));c.appendChild(n);this.load('https://dev.visualwebsiteoptimizer.com/j.php?a='+account_id+'&u='+encodeURIComponent(d.URL)+'&vn='+version)}};w._vwo_code=code;code.init();})();
# </script>
# <!-- End VWO Async SmartCode -->
# <style>html{-webkit-text-size-adjust:100%}body{margin:0}@font-face{font-family:Manrope;font-style:normal;font-weight:200;font-display:swap;src:url(https://fonts.gstatic.com/s/manrope/v11/xn7gYHE41ni1AdIRggmxSuXd.woff2) format("woff2");unicode-range:U+0100-024F,U+0259,U+1E00-1EFF,U+2020,U+20A0-20AB,U+20AD-20CF,U+2113,U+2C60-2C7F,U+A720-A7FF}@font-face{font-family:Manrope;font-style:normal;font-weight:200;font-display:swap;src:url(https://fonts.gstatic.com/s/manrope/v11/xn7gYHE41ni1AdIRggexSg.woff2) format("woff2");unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+2000-206F,U+2074,U+20AC,U+2122,U+2191,U+2193,U+2212,U+2215,U+FEFF,U+FFFD}@font-face{font-family:Manrope;font-style:normal;font-weight:300;font-display:swap;src:url(https://fonts.gstatic.com/s/manrope/v11/xn7gYHE41ni1AdIRggmxSuXd.woff2) format("woff2");unicode-range:U+0100-024F,U+0259,U+1E00-1EFF,U+2020,U+20A0-20AB,U+20AD-20CF,U+2113,U+2C60-2C7F,U+A720-A7FF}@font-face{font-family:Manrope;font-style:normal;font-weight:300;font-display:swap;src:url(https://fonts.gstatic.com/s/manrope/v11/xn7gYHE41ni1AdIRggexSg.woff2) format("woff2");unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+2000-206F,U+2074,U+20AC,U+2122,U+2191,U+2193,U+2212,U+2215,U+FEFF,U+FFFD}@font-face{font-family:Manrope;font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/manrope/v11/xn7gYHE41ni1AdIRggmxSuXd.woff2) format("woff2");unicode-range:U+0100-024F,U+0259,U+1E00-1EFF,U+2020,U+20A0-20AB,U+20AD-20CF,U+2113,U+2C60-2C7F,U+A720-A7FF}@font-face{font-family:Manrope;font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/manrope/v11/xn7gYHE41ni1AdIRggexSg.woff2) format("woff2");unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+2000-206F,U+2074,U+20AC,U+2122,U+2191,U+2193,U+2212,U+2215,U+FEFF,U+FFFD}@font-face{font-family:Manrope;font-style:normal;font-weight:500;font-display:swap;src:url(https://fonts.gstatic.com/s/manrope/v11/xn7gYHE41ni1AdIRggmxSuXd.woff2) format("woff2");unicode-range:U+0100-024F,U+0259,U+1E00-1EFF,U+2020,U+20A0-20AB,U+20AD-20CF,U+2113,U+2C60-2C7F,U+A720-A7FF}@font-face{font-family:Manrope;font-style:normal;font-weight:500;font-display:swap;src:url(https://fonts.gstatic.com/s/manrope/v11/xn7gYHE41ni1AdIRggexSg.woff2) format("woff2");unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+2000-206F,U+2074,U+20AC,U+2122,U+2191,U+2193,U+2212,U+2215,U+FEFF,U+FFFD}@font-face{font-family:Manrope;font-style:normal;font-weight:600;font-display:swap;src:url(https://fonts.gstatic.com/s/manrope/v11/xn7gYHE41ni1AdIRggmxSuXd.woff2) format("woff2");unicode-range:U+0100-024F,U+0259,U+1E00-1EFF,U+2020,U+20A0-20AB,U+20AD-20CF,U+2113,U+2C60-2C7F,U+A720-A7FF}@font-face{font-family:Manrope;font-style:normal;font-weight:600;font-display:swap;src:url(https://fonts.gstatic.com/s/manrope/v11/xn7gYHE41ni1AdIRggexSg.woff2) format("woff2");unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+2000-206F,U+2074,U+20AC,U+2122,U+2191,U+2193,U+2212,U+2215,U+FEFF,U+FFFD}@font-face{font-family:Manrope;font-style:normal;font-weight:700;font-display:swap;src:url(https://fonts.gstatic.com/s/manrope/v11/xn7gYHE41ni1AdIRggmxSuXd.woff2) format("woff2");unicode-range:U+0100-024F,U+0259,U+1E00-1EFF,U+2020,U+20A0-20AB,U+20AD-20CF,U+2113,U+2C60-2C7F,U+A720-A7FF}@font-face{font-family:Manrope;font-style:normal;font-weight:700;font-display:swap;src:url(https://fonts.gstatic.com/s/manrope/v11/xn7gYHE41ni1AdIRggexSg.woff2) format("woff2");unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+2000-206F,U+2074,U+20AC,U+2122,U+2191,U+2193,U+2212,U+2215,U+FEFF,U+FFFD}@font-face{font-family:Manrope;font-style:normal;font-weight:800;font-display:swap;src:url(https://fonts.gstatic.com/s/manrope/v11/xn7gYHE41ni1AdIRggmxSuXd.woff2) format("woff2");unicode-range:U+0100-024F,U+0259,U+1E00-1EFF,U+2020,U+20A0-20AB,U+20A ...
# </style><style ng-transition="serverApp">.bop-widget-screen-content[_ngcontent-sc176]{display:flex;flex-direction:column;align-items:center}.bop-widget-screen-content[_ngcontent-sc176]   .bop-widget-screen-line-1[_ngcontent-sc176]{margin-top:12px}.bop-widget-screen-content[_ngcontent-sc176]   .bop-widget-screen-line-1[_ngcontent-sc176]   .bop-widget-dot-icon[_ngcontent-sc176]{margin-right:4px}.bop-widget-screen-content[_ngcontent-sc176]   .bop-widget-screen-line-2[_ngcontent-sc176]{display:flex;flex-direction:column;align-items:center}.bop-widget-screen-content[_ngcontent-sc176]   .expert-available-timing-section[_ngcontent-sc176]{color:#848484}.bop-widget-screen-content[_ngcontent-sc176]   .bop-widget-screen-line-3[_ngcontent-sc176]{display:flex;justify-content:center;align-items:center}.bop-widget-screen-content[_ngcontent-sc176]   .bop-widget-screen-line-3[_ngcontent-sc176]   .bop-caller-icon[_ngcontent-sc176]{display:flex;margin-right:2px}.bop-widget-screen-content[_ngcontent-sc176]   .divider[_ngcontent-sc176]{display:flex;align-items:center;width:100%}.bop-widget-screen-content[_ngcontent-sc176]   .divider[_ngcontent-sc176]:before, .bop-widget-screen-content[_ngcontent-sc176]   .divider[_ngcontent-sc176]:after{content:"";flex:1;border-bottom:1px solid #E0E0E0;margin:0 8px}  .button-container span{margin-right:4px}.bop-widget-random-expert-text[_ngcontent-sc176]{color:#67ad5b}@keyframes blink{0%{opacity:1}50%{opacity:0}to{opacity:1}}.blink[_ngcontent-sc176]{animation:blink 1s infinite}</style><style ng-transition="serverApp">.button-container{font-size:.875rem;line-height:1.375rem;padding:12px 16px;color:#fff;transition:all .3s ease-in;cursor:pointer;font-weight:700;border-radius:2px;border:none;background:transparent}@media only screen and (min-width : 1024px){.button-container{font-size:1rem;padding:12px 16px}}.button-block{width:100%}.button-primary{background-image:linear-gradient(180deg,rgba(246,77,24,.99) 0%,#FF7035 100%)}.button-primary:hover{background-color:#ff8d5d;background-image:linear-gradient(180deg,#FF8D5D 0%,#FF8D5D 100%)}.button-secondary{background-color:#1979b5;background-image:none}.button-success{background-color:#85bd7c;background-image:none}.button-info{background-color:#4794c4;background-image:none}.button-warning{background-color:#f69a23;background-image:none}.button-link{background-color:#ff7035}.button-rounded{border-radius:50px}.button-solid{color:#fff;border:none}.button-outline{border:solid 1px #E0E0E0;color:#5b5b5b}.button-outline:hover{background-color:#f5f5f5}.button-outline-orange{border:solid 1px #FF7035;color:#ff7035}.button-outline-orange:hover{background-color:#ffe2d7}.button-dashed{border:dashed 1px #FF7035;color:#ff7035}.button-size--large{padding:12px 16px;font-size:.875rem;line-height:1.25rem}@media only screen and (min-width : 1280px){.button-size--large{font-size:1rem;line-height:1.5rem}}.button-size--base{padding:10px 32px;font-size:.875rem;line-height:1.25rem}.button-size--medium{padding:8px 16px;font-size:.875rem;line-height:1.25rem}@media only screen and (min-width : 1280px){.button-size--medium{font-size:1rem;line-height:1.5rem}}.button-size--small{padding:8px 16px;font-size:.625rem;line-height:1rem}@media only screen and (min-width : 768px){.button-size--small{font-size:.75rem;line-height:1.25rem}}@media only screen and (min-width : 1280px){.button-size--small{font-size:.875rem;line-height:1.5rem}}.button-default{width:100%}.button-icon{width:46px;height:46px}[disabled]{background-color:#e0e0e0;background-image:none;cursor:default;pointer-events:none}.button-text-large,.button-text-medium,.button-text-small{color:#ff7035}.button-text-large,.button-text-medium{font-size:.875rem;line-height:1.25rem;font-weight:700}@media only screen and (min-width : 1280px){.button-text-large,.button-text-medium{font-size:1rem;line-height:1.5rem}}.button-text-small{font-size:.625rem;line-height:1rem;font-weight:700}@media only screen and (min-width : 768px){.button-text-small{font-size:.75re ...
# </style><style ng-transition="serverApp">.header-main-section[_ngcontent-sc175]{position:relative;background-color:#fff;width:100%}@media only screen and (max-width : 1023px){.header-main-section[_ngcontent-sc175]{border-bottom:1px solid #F5F5F5}}@media only screen and (min-width : 1024px){.main-header[_ngcontent-sc175]{min-height:152px}}@media only screen and (min-width : 768px) and (max-width : 1023px){.main-header[_ngcontent-sc175]{min-height:61px}}@media only screen and (max-width : 767px){.main-header[_ngcontent-sc175]{min-height:0}}@media only screen and (min-width : 1024px){.zIndex[_ngcontent-sc175]{z-index:901}}.ctg-header-main-section[_ngcontent-sc175]{z-index:980;top:0;position:fixed}#menuTransOverlay[_ngcontent-sc175]{position:fixed;width:100%;height:100%;z-index:700;left:0;top:0;display:none;background-color:#00000042}#menuTransOverlay.active[_ngcontent-sc175]{display:block}@media only screen and (max-width : 767px){#menuTransOverlay.active[_ngcontent-sc175]{display:none}}</style><style ng-transition="serverApp">.hd-promo-wrap[_ngcontent-sc170]{background:#121212;color:#fff;padding:10px 0}@media only screen and (max-width : 767px){.hd-promo-wrap[_ngcontent-sc170]{padding:5px 0}}.hd-mobile-promo-banner[_ngcontent-sc170]{height:55px;display:flex;align-items:center;overflow:hidden}.hd-mobile-promo-banner[_ngcontent-sc170]   .hd-mobile-promo-text[_ngcontent-sc170]{width:calc(100% - 48px);color:#fff;padding:4px 4px 4px 16px}.hd-mobile-promo-banner[_ngcontent-sc170]   .hd-mobile-promo-text[_ngcontent-sc170]   .hd-mobile-offer-sale[_ngcontent-sc170]{display:block}.hd-mobile-promo-banner[_ngcontent-sc170]   .hd-mobile-close-section[_ngcontent-sc170]{width:48px;height:56px;display:flex;align-items:center;justify-content:center}.hd-mobile-promo-banner[_ngcontent-sc170]   .hd-mobile-close-section[_ngcontent-sc170]   img[_ngcontent-sc170]{width:auto;height:auto;max-width:100%}@media only screen and (min-width : 768px){.hd-mobile-promo-banner[_ngcontent-sc170]{display:none}}</style><style ng-transition="serverApp">#signup-sucess-popup-overlay-wrap[_ngcontent-sc174]{position:fixed;width:100%;height:100%;inset:0;background-color:#00000080;z-index:10000;cursor:pointer;-webkit-tap-highlight-color:transparent}.success-popup-content-wrap[_ngcontent-sc174]{position:fixed;top:50%;left:50%;transform:translate(-50%,-50%)}.wap-content[_ngcontent-sc174]{width:328px;height:173px}.web-content[_ngcontent-sc174]{width:417px;height:616px}.success-popup-content[_ngcontent-sc174]{display:inline-block;position:relative;cursor:default}.success-popup-content[_ngcontent-sc174]   .close-wrapper[_ngcontent-sc174]{position:absolute;width:24px;height:24px;top:11px;right:15px;cursor:pointer}.success-popup-content[_ngcontent-sc174]   .close-wrapper-wap[_ngcontent-sc174]{position:absolute;width:24px;height:24px;top:4px;right:14px;cursor:pointer}</style><style ng-transition="serverApp">[_nghost-sc158]{--footer-bottom: 20px}footer[_ngcontent-sc158]{width:100%}footer[_ngcontent-sc158]   .footer-wrapper[_ngcontent-sc158]{background-color:#f5f5f5}@media only screen and (max-width : 767px){footer[_ngcontent-sc158]   .footer-margin-bottom[_ngcontent-sc158]{margin-bottom:69px}}footer[_ngcontent-sc158]   .row[_ngcontent-sc158]{display:flex;justify-content:space-between}footer[_ngcontent-sc158]   .row[_ngcontent-sc158]   .footer-col[_ngcontent-sc158]{width:18%}footer[_ngcontent-sc158]   .row[_ngcontent-sc158]   .footer-col[_ngcontent-sc158]   p[_ngcontent-sc158]{margin:0 0 8px}footer[_ngcontent-sc158]   .ul-flex[_ngcontent-sc158]{display:flex;flex-direction:column}footer[_ngcontent-sc158]   .store-images-wrapper[_ngcontent-sc158]{align-items:center}footer[_ngcontent-sc158]   .second-row-section[_ngcontent-sc158]{padding:80px 0 40px}@media only screen and (min-width : 768px){footer[_ngcontent-sc158]   .second-row-section[_ngcontent-sc158]   .footer-col[_ngcontent-sc158]{width:30%}}footer[_ngcontent-sc158]   li[_ngcontent-sc158]{list-style-type:none;display:inline-bloc ...
# </style><style ng-transition="serverApp">@media only screen and (min-width : 768px){[_nghost-sc156]  .card-icons .picture-image-cls-container img{width:44px}}@media only screen and (min-width : 1024px){[_nghost-sc156]  .card-icons .picture-image-cls-container img{width:56px}}@media only screen and (min-width : 1280px){[_nghost-sc156]  .card-icons .picture-image-cls-container img{width:76px}}.accept-cards[_ngcontent-sc156]   .accept-header[_ngcontent-sc156]{margin-top:0}@media only screen and (max-width : 767px){.accept-cards[_ngcontent-sc156]   .accept-header[_ngcontent-sc156]{margin-top:28px}}.accept-card-icons[_ngcontent-sc156]{display:flex;flex-direction:row;flex:1}@media only screen and (max-width : 767px){.accept-card-icons[_ngcontent-sc156]{margin-bottom:28px}}.accept-card-icons[_ngcontent-sc156]   .accept-card-icon[_ngcontent-sc156]{margin-right:4px}</style><style ng-transition="serverApp">.social-icon-wrapper[_ngcontent-sc157]{display:flex;width:100%;justify-content:center}@media only screen and (min-width : 768px){.social-icon-section[_ngcontent-sc157]{margin:0}}.social-icon-heading[_ngcontent-sc157]{margin:20px auto 8px}@media only screen and (min-width : 768px){.social-icon-heading[_ngcontent-sc157]{margin-top:0}}[_nghost-sc157]  .social-icons .picture-image-container img{width:28px;height:28px;margin-right:12px}@media only screen and (min-width : 1024px){[_nghost-sc157]  .social-icons .picture-image-container img{width:32px;height:32px;margin-right:20px}}@media only screen and (min-width : 1280px){[_nghost-sc157]  .social-icons .picture-image-container img{width:46px;height:46px}}</style><style ng-transition="serverApp">.legal-pages-section[_ngcontent-sc155]{justify-content:center}@media only screen and (max-width : 767px){.legal-pages-section[_ngcontent-sc155]{justify-content:flex-start}}@media only screen and (min-width : 768px){.legal-pages-section[_ngcontent-sc155]   a[_ngcontent-sc155]{padding-right:12px}}@media only screen and (min-width : 1024px){.legal-pages-section[_ngcontent-sc155]   a[_ngcontent-sc155]{padding-right:20px}}.legal-pages-section[_ngcontent-sc155]   .legal-pages-mobile[_ngcontent-sc155]   span[_ngcontent-sc155]{padding:0 4px}</style><style ng-transition="serverApp">.category-page-skeleton[_ngcontent-sc278]   img[_ngcontent-sc278]{width:100%}</style><link class="canonical-element" href="https://www.pepperfry.com/site_product/search" rel="canonical"/><style ng-transition="serverApp">@media only screen and (max-width : 767px){.clip-page-container[_ngcontent-sc277]   .clip-filter-view[_ngcontent-sc277]{display:flex;flex-direction:column}}.clip-page-container[_ngcontent-sc277]   .clip-filter-view[_ngcontent-sc277]   .microsite-heading[_ngcontent-sc277]{margin-top:8px;color:#c6a787}.clip-page-container[_ngcontent-sc277]   .clip-filter-view[_ngcontent-sc277]   .microsite-subheading[_ngcontent-sc277]{color:#121212;max-width:800px;display:inline-block}.clip-page-container[_ngcontent-sc277]   .clip-filter-view[_ngcontent-sc277]   .clip-filter-wrapper[_ngcontent-sc277]{background-color:#fafafa}@media only screen and (max-width : 767px){.clip-page-container[_ngcontent-sc277]   .clip-filter-view[_ngcontent-sc277]   .clip-filter-wrapper[_ngcontent-sc277]{order:1}}@media only screen and (max-width : 767px){.clip-page-container[_ngcontent-sc277]   .clip-filter-view[_ngcontent-sc277]   .clip-header-wrapper[_ngcontent-sc277]{order:2}}.clip-page-container[_ngcontent-sc277]   .clip-filter-view[_ngcontent-sc277]   .clip-header-wrapper-search[_ngcontent-sc277]{padding-top:8px}@media only screen and (min-width : 768px){.clip-page-container[_ngcontent-sc277]   .clip-product-listing-wrapper[_ngcontent-sc277]{background-color:#f5f5f5}}.clip-page-container[_ngcontent-sc277]   .clip-product-listing-wrapper[_ngcontent-sc277]   .search-result[_ngcontent-sc277]{display:flex}.clip-page-container[_ngcontent-sc277]   .clip-product-listing-wrapper[_ngcontent-sc277]   .search-result[_ngcontent-sc277]   h1[_ngcontent-sc277]{mar ...
# </style><style ng-transition="serverApp">[_nghost-sc257]  .picture-image-container .picture-img-tag{width:100%}.clip-header-container[_ngcontent-sc257]   .microsite-heading[_ngcontent-sc257]{margin-top:8px;color:#9d6a37}.clip-header-container[_ngcontent-sc257]   .isMicroSite[_ngcontent-sc257]{display:none}.clip-header-container[_ngcontent-sc257]   .microsite-subheading[_ngcontent-sc257]{color:#121212;max-width:800px;display:inline-block}.clip-header-container[_ngcontent-sc257]   .clip-header-breadcrumb[_ngcontent-sc257]{display:inline-block;margin:auto}@media only screen and (min-width : 768px){.clip-header-container[_ngcontent-sc257]   .clip-ctg-row[_ngcontent-sc257]{display:block;margin:auto;padding:0}}.clip-header-container[_ngcontent-sc257]   .clip-ctg-row[_ngcontent-sc257]   .clip-ctg-row-section[_ngcontent-sc257]{margin:auto}@media only screen and (max-width : 767px){.clip-header-container[_ngcontent-sc257]   .clip-ctg-row[_ngcontent-sc257]   .clip-ctg-row-section[_ngcontent-sc257]{padding-left:8px;width:100%}}@media only screen and (min-width : 768px){.clip-header-container[_ngcontent-sc257]   .clip-ctg-row[_ngcontent-sc257]   .clip-ctg-row-section[_ngcontent-sc257]{width:90%}}@media only screen and (min-width : 1280px){.clip-header-container[_ngcontent-sc257]   .clip-ctg-row[_ngcontent-sc257]   .clip-ctg-row-section[_ngcontent-sc257]{width:90%}}.clip-header-container[_ngcontent-sc257]   .clip-ctg-row[_ngcontent-sc257]:nth-child(2)   .clip-ctg-row-bg[_ngcontent-sc257]{background-color:#fafafa;padding:10px 30px;border-top:1px solid #EEEEEE}.clip-header-container[_ngcontent-sc257]   .clip-ctg-row[_ngcontent-sc257]:nth-child(3)   .clip-ctg-row-bg[_ngcontent-sc257]{background-color:#f5f5f5;padding:10px 30px;border-top:1px solid #E0E0E0}.clip-header-container[_ngcontent-sc257]   .clip-ctg-row[_ngcontent-sc257]:nth-child(4)   .clip-ctg-row-bg[_ngcontent-sc257]{background-color:#fafafa;padding:10px 30px;border-top:1px solid #EEEEEE}.clip-header-container[_ngcontent-sc257]   .clip-ctg-row[_ngcontent-sc257]:nth-child(5)   .clip-ctg-row-bg[_ngcontent-sc257]{background-color:#f5f5f5;padding:10px 30px;border-top:1px solid #E0E0E0}.clip-header-container[_ngcontent-sc257]   .clip-ctg-row[_ngcontent-sc257]   .clip-ctg-col[_ngcontent-sc257]{margin:2px;display:inline-block}@media only screen and (max-width : 767px){.clip-header-container[_ngcontent-sc257]   .pf-css-slider[_ngcontent-sc257]   .row[_ngcontent-sc257]{padding-bottom:initial;margin-bottom:initial}}[_nghost-sc257]  .owl-theme .owl-nav{margin-top:0}[_nghost-sc257]  .clip-ctg-row-section .owl-stage{margin:auto;display:-webkit-box}[_nghost-sc257]  .clip-ctg-row-section .owl-stage .owl-item{padding-right:12px;text-align:center;margin-right:4px}[_nghost-sc257]  .clip-ctg-row-section .owl-stage .owl-item img{width:auto;margin:auto}[_nghost-sc257]  .clip-ctg-row-section .owl-nav .owl-prev.disabled+.owl-next.disabled{display:none}[_nghost-sc257]  .clip-ctg-row-section .owl-nav .eleDisable{display:none}[_nghost-sc257]  .clip-ctg-row-section .owl-carousel .prev-slide{left:-50px;border:1px solid #E0E0E0}[_nghost-sc257]  .clip-ctg-row-section .owl-carousel .next-slide{right:-60px;border:1px solid #E0E0E0}[_nghost-sc257]  .clip-ctg-row:nth-child(2) .owl-item, [_nghost-sc257]  .clip-ctg-row:nth-child(3) .owl-item, [_nghost-sc257]  .clip-ctg-row:nth-child(4) .owl-item, [_nghost-sc257]  .clip-ctg-row:nth-child(5) .owl-item{width:auto!important}.clip-header-brand[_ngcontent-sc257]{margin:auto}.clip-header-brand[_ngcontent-sc257]   .clip-brand-content[_ngcontent-sc257]   p[_ngcontent-sc257]{margin:0}@media only screen and (max-width : 767px){.clip-header-brand[_ngcontent-sc257]{padding:12px 8px}.clip-header-brand[_ngcontent-sc257]   .clip-brand-img[_ngcontent-sc257], .clip-header-brand[_ngcontent-sc257]   .clip-brand-top-section[_ngcontent-sc257]{margin-bottom:12px}}@media only screen and (min-width : 768px){.clip-header-brand[_ngcontent-sc257]{padding:18px 0;width:94%}.clip-header-brand[_ngco ...
# </style><style ng-transition="serverApp">.owl-theme[_ngcontent-sc87]{display:block}</style><style ng-transition="serverApp">.clip-catg-list[_ngcontent-sc255]{height:100%}.clip-catg-list[_ngcontent-sc255]   .clip-catg-listing[_ngcontent-sc255]{cursor:pointer}.clip-catg-list[_ngcontent-sc255]   .clip-catg-card-wrapper[_ngcontent-sc255]{border:2px solid transparent;transition:all .3s ease-in-out;display:inline-block;padding:4px 8px;height:100%}.clip-catg-list[_ngcontent-sc255]   .clip-catg-card-wrapper[_ngcontent-sc255]   .clipCategoryDataImg[_ngcontent-sc255]{display:block;height:auto;width:100%}@media only screen and (max-width : 767px){.clip-catg-list[_ngcontent-sc255]   .clip-catg-card-wrapper[_ngcontent-sc255]{width:82px;padding:4px 0}}@media only screen and (min-width : 768px){.clip-catg-list[_ngcontent-sc255]   .clip-catg-card-wrapper[_ngcontent-sc255]{width:125px}}.clip-catg-list.clip-catg-selected[_ngcontent-sc255]   .clip-catg-card-wrapper[_ngcontent-sc255]{cursor:default}.clip-catg-list.clip-catg-selected[_ngcontent-sc255]   .clip-catg-card-wrapper[_ngcontent-sc255]{position:relative}@media only screen and (min-width : 768px){.clip-catg-list.clip-catg-selected[_ngcontent-sc255]   .clip-catg-card-wrapper[_ngcontent-sc255]{border:1px solid #EEDECE}}.clip-catg-list.clip-catg-selected[_ngcontent-sc255]   .clip-catg-card-wrapper[_ngcontent-sc255]:after{content:"";background:url(https://ii1.pepperfry.com/assets/w23-clip-arrow-round.svg) no-repeat center;background-size:20px;width:20px;height:20px;position:absolute;left:0;top:0}@media only screen and (min-width : 768px){.clip-catg-list.clip-catg-selected[_ngcontent-sc255]   .clip-catg-card-wrapper[_ngcontent-sc255]:after{left:50%;top:50%;transform:translate(-50%,-50%)}}.clip-catg-list.clip-catg-selected[_ngcontent-sc255]   .clip-catg-card-wrapper[_ngcontent-sc255]   .clip-catg-title[_ngcontent-sc255], .clip-catg-list.clip-catg-selected[_ngcontent-sc255]   .clip-catg-card-wrapper[_ngcontent-sc255]   .clip-catg-content[_ngcontent-sc255]{color:#ff7035}.clip-catg-list[_ngcontent-sc255]   .clip-catg-card-wrapper[_ngcontent-sc255]:hover{position:relative}@media only screen and (min-width : 768px){.clip-catg-list[_ngcontent-sc255]   .clip-catg-card-wrapper[_ngcontent-sc255]:hover{box-shadow:inset -2px 0 #ff7035,inset 0 -2px #ff7035,inset 2px 0 #ff7035,inset 0 2px #ff7035}}@media only screen and (min-width : 768px){.clip-catg-list[_ngcontent-sc255]   .clip-catg-card-wrapper[_ngcontent-sc255]:hover:after{left:50%;top:50%;transform:translate(-50%,-50%)}}.clip-catg-list[_ngcontent-sc255]   .clip-subcatg-tab-wrapper[_ngcontent-sc255]{padding:4px 8px;border:1px solid #E0E0E0;border-radius:2px;transition:all .3s ease-in}.clip-catg-list[_ngcontent-sc255]   .clip-subcatg-tab-wrapper[_ngcontent-sc255]:hover{background-color:#eee}.clip-catg-list.clip-catg-selected[_ngcontent-sc255]   .clip-subcatg-tab-wrapper[_ngcontent-sc255], .clip-catg-list.clip-catg-selected[_ngcontent-sc255]   .clip-subcatg-tab-wrapper[_ngcontent-sc255]   .color-secondary[_ngcontent-sc255], .clip-catg-list.clip-catg-selected[_ngcontent-sc255]   .clip-subcatg-tab-wrapper[_ngcontent-sc255]:hover{color:#9d6a37;background-color:transparent}.clip-catg-list.clip-catg-selected[_ngcontent-sc255]   .clip-subcatg-tab-wrapper[_ngcontent-sc255]{background:url(https://ii1.pepperfry.com/assets/w23-sub-ctg-arrow-active.svg) no-repeat 6px center;padding-left:22px;cursor:default}@media only screen and (max-width : 767px){.clip-catg-list[_ngcontent-sc255]   .clip-ctg-all-card[_ngcontent-sc255]{height:54px}}.ctg-white-space[_ngcontent-sc255]{white-space:break-spaces}[_nghost-sc255]  .clip-catg-card-wrapper pf-image img{height:54px}@media only screen and (min-width : 768px){[_nghost-sc255]  .clip-catg-card-wrapper pf-image img{height:66px}}[_nghost-sc255]  .clip-catg-selected .clip-catg-card-wrapper pf-image{opacity:.2}[_nghost-sc255]  .clip-catg-listing pf-image .image-cls-container{background-color:transparent}</style><style ng-transition= ...
# </style><style ng-transition="serverApp">.product-card-container[_ngcontent-sc259]   img[_ngcontent-sc259]{width:auto;height:auto;max-width:100%}.product-card-container[_ngcontent-sc259]   .product-card-image[_ngcontent-sc259]{cursor:pointer;text-align:center;min-height:150px}@media only screen and (min-width : 768px) and (max-width : 1023px){.product-card-container[_ngcontent-sc259]   .product-card-image[_ngcontent-sc259]{min-height:180px}}@media only screen and (min-width : 1024px) and (max-width : 1279px){.product-card-container[_ngcontent-sc259]   .product-card-image[_ngcontent-sc259]{min-height:210px}}@media only screen and (min-width : 1280px){.product-card-container[_ngcontent-sc259]   .product-card-image[_ngcontent-sc259]{min-height:280px}}.product-card-container[_ngcontent-sc259]   .product-card-top[_ngcontent-sc259]{position:relative}.product-card-container[_ngcontent-sc259]   .product-card-top[_ngcontent-sc259]   .product-card-wishlist[_ngcontent-sc259]{position:absolute;bottom:-12px;right:8px;z-index:2;cursor:pointer}@media only screen and (min-width : 1280px){.product-card-container[_ngcontent-sc259]   .product-card-top[_ngcontent-sc259]   .product-card-wishlist[_ngcontent-sc259]{bottom:-17px}}@media only screen and (min-width : 768px){.product-card-container[_ngcontent-sc259]   .product-card-top[_ngcontent-sc259]   .product-card-wishlist[_ngcontent-sc259]   img[_ngcontent-sc259]{width:24px;height:24px}}@media only screen and (min-width : 1280px){.product-card-container[_ngcontent-sc259]   .product-card-top[_ngcontent-sc259]   .product-card-wishlist[_ngcontent-sc259]   img[_ngcontent-sc259]{width:32px;height:32px}}.product-card-container[_ngcontent-sc259]   .product-card-top[_ngcontent-sc259]   .product-card-tag[_ngcontent-sc259]{position:absolute;top:0;left:0}.product-card-container[_ngcontent-sc259]   .product-card-top[_ngcontent-sc259]   .product-card-tag[_ngcontent-sc259]   .product-tag-label[_ngcontent-sc259]{padding:4px;background-color:#ff7035;color:#fff;transition:all .3s ease-in-out;border-radius:2px}@media only screen and (min-width : 1024px){.product-card-container[_ngcontent-sc259]   .product-card-top[_ngcontent-sc259]   .product-card-tag[_ngcontent-sc259]   .product-tag-label[_ngcontent-sc259]{padding:8px}}.product-card-container[_ngcontent-sc259]   .product-card-top[_ngcontent-sc259]   .product-already-in-cart-tag[_ngcontent-sc259]{position:absolute;bottom:0;width:100%}.product-card-container[_ngcontent-sc259]   .product-card-top[_ngcontent-sc259]   .product-already-in-cart-tag[_ngcontent-sc259]   .product-tag-label[_ngcontent-sc259]{text-align:center;padding:7px 0;background-color:#121212cc;color:#fff;transition:all .3s ease-in-out;border-radius:2px}@media only screen and (min-width : 768px){.product-card-container[_ngcontent-sc259]   .product-card-top[_ngcontent-sc259]   .product-already-in-cart-tag[_ngcontent-sc259]   .product-tag-label[_ngcontent-sc259]{padding:12px 0;height:40px}}@media only screen and (min-width : 1024px){.product-card-container[_ngcontent-sc259]   .product-card-top[_ngcontent-sc259]   .product-already-in-cart-tag[_ngcontent-sc259]   .product-tag-label[_ngcontent-sc259]{padding:12px 0;height:44px}}@media only screen and (min-width : 1280px){.product-card-container[_ngcontent-sc259]   .product-card-top[_ngcontent-sc259]   .product-already-in-cart-tag[_ngcontent-sc259]   .product-tag-label[_ngcontent-sc259]{padding:8px;height:37px}}.product-card-container[_ngcontent-sc259]   .product-card-bottom[_ngcontent-sc259]   .product-price[_ngcontent-sc259]   .product-offer-price[_ngcontent-sc259]{margin-right:4px}.product-card-container[_ngcontent-sc259]   .product-card-bottom[_ngcontent-sc259]   .product-rating-wrapper[_ngcontent-sc259]{display:flex}@media only screen and (max-width : 1023px){.product-card-container[_ngcontent-sc259]   .product-card-bottom[_ngcontent-sc259]   .product-rating-wrapper[_ngcontent-sc259]{flex-direction:column}}@media only screen and (min-width : 1024px){.pro ...
# <body>
# <app-root _nghost-sc181="" ng-server-context="other" ng-version="14.3.0"><pf-header _ngcontent-sc181="" _nghost-sc175=""><header _ngcontent-sc175="" class="header-main-section zIndex"><div _ngcontent-sc175="" class="promo-header"><pf-header-promo _ngcontent-sc175="" _nghost-sc170=""><!-- --><!-- --><!-- --></pf-header-promo></div><div _ngcontent-sc175="" class=""><pf-header-main _ngcontent-sc175="" _nghost-sc169=""><div _ngcontent-sc169="" class="main-header-container"><nav _ngcontent-sc169="" class="header-corporate-links"><ul _ngcontent-sc169="" class="hd-list-container container"><li _ngcontent-sc169="" class="hd-list-item uppercase"><a _ngcontent-sc169="" class="text-sm" data-test="sellOnPepperfry" href="/form/partners-partnerwithus.html?partner=seller&amp;type=header" routerlink="/form/partners-partnerwithus.html">Sell on pepperfry</a><!-- --><!-- --></li><li _ngcontent-sc169="" class="hd-list-item uppercase"><a _ngcontent-sc169="" class="text-sm" data-test="franchise" href="/form/partners-franchisee.html?type=header" routerlink="/form/partners-franchisee.html">Become a franchisee</a><!-- --><!-- --></li><li _ngcontent-sc169="" class="hd-list-item uppercase"><a _ngcontent-sc169="" class="text-sm" data-test="bulkOrder" href="/form/partners-bulkorder.html?type=header" routerlink="/form/partners-bulkorder.html">Buy in Bulk</a><!-- --><!-- --></li><li _ngcontent-sc169="" class="hd-list-item uppercase"><a _ngcontent-sc169="" class="text-sm" data-test="giftCard" href="/form/pepperfry-gift-cards.html?type=header" routerlink="/form/pepperfry-gift-cards.html">GIFT CARDS</a><!-- --><!-- --></li><li _ngcontent-sc169="" class="hd-list-item uppercase"><a _ngcontent-sc169="" class="text-sm" data-test="designInspiration" href="https://www.pepperfry.com/pages/design_inspiration.html?type=header">GET INSPIRED</a></li><li _ngcontent-sc169="" class="hd-list-item uppercase"><a _ngcontent-sc169="" class="text-sm" data-test="trackOrder" href="https://www.pepperfry.com/customer/myorders">Track Your Order</a></li><li _ngcontent-sc169="" class="hd-list-item uppercase"><a _ngcontent-sc169="" class="text-sm" data-test="contactUs" href="https://www.pepperfry.com/customer/needhelp/contactus">Contact us</a></li></ul></nav><div _ngcontent-sc169="" class="container"><div _ngcontent-sc169="" class="hd-main-menu-container"><div _ngcontent-sc169="" class="hd-mobile-hamburger-responsive cursor-pointer"><a _ngcontent-sc169="" class="hd-hamburger-cta cursor-pointer" role="link"><img _ngcontent-sc169="" alt="hamburger icon" src="https://ii1.pepperfry.com/assets/w38-hamburger.svg"/></a></div><div _ngcontent-sc169="" appclickoutside="" class="header-search"><div _ngcontent-sc169="" class="hd-search-wrap"><div _ngcontent-sc169="" class="hd-search-bar"><input _ngcontent-sc169="" autocomplete="off" class="hd-search-bar-inpt text-md ng-untouched ng-pristine ng-valid" data-test="searchInput" id="search" maxlength="100" name="q" pf-whitespace-validate="" placeholder="Search" type="text" value=""/><button _ngcontent-sc169="" class="hd-search-btn" data-test="searchIcon" id="searchButton" type="button"><img _ngcontent-sc169="" alt="search-icon" height="14" src="https://ii1.pepperfry.com/assets/w38-search-web.svg" width="14"/></button><!-- --><!-- --></div></div><!-- --></div><div _ngcontent-sc169="" class="hd-logo-wrap"><a _ngcontent-sc169="" class="pf-logo" data-test="pepperfryLogo" href="/"><img _ngcontent-sc169="" alt="PepperfryLogo" height="47" src="https://ii1.pepperfry.com/assets/w38-pf-logo-desktop.svg" width="219"/></a><!-- --><!-- --></div><div _ngcontent-sc169="" class="header-icons"><pf-header-icons _ngcontent-sc169="" _nghost-sc166=""><div _ngcontent-sc166="" class="hd-icon-wrapper"><div _ngcontent-sc166="" class="hd-profile-wrap hd-menu-level-top" hover-class="active"><div _ngcontent-sc166="" class="wrap-text-icon"><div _ngcontent-sc166="" class="user-credit-text cursor-pointer"><div _ngcontent-sc166="" class="sign-up-text text-xs font-semibold text-right">S ...
# <script fetchpriority="high" src="runtime.29ce6eabdc558575.js" type="module"></script><script fetchpriority="high" src="polyfills.ce4a028b01835e3d.js" type="module"></script><script fetchpriority="high" src="vendor.f484dac730b46ff5.js" type="module"></script><script fetchpriority="high" src="main.a0a1c3a979f90338.js" type="module"></script>
# <noscript async="true"><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-TWGMR3" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <noscript async="true">
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-K8V3Z8" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <noscript defer=""><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-N92Z4HX" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <noscript defer=""><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-T5D99ZQ" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <noscript>
# <img src="www.pepperfry.com/logger/noscript"/>
# </noscript>
# <!-- <script defer>
#   if (window.innerWidth <= 720) {
#   !function(t,e,n,s,a,c,i,o,p){t.AppsFlyerSdkObject=a,t.AF=t.AF||function(){(t.AF.q=t.AF.q||[]).push([Date.now()].concat(Array.prototype.slice.call(arguments)))},t.AF.id=t.AF.id||i,t.AF.plugins={},o=e.createElement(n),p=e.getElementsByTagName(n)[0],o.defer=1,o.src="https://websdk.appsflyer.com?"+(c.length>0?"st="+c.split(",").sort().join(",")+"&":"")+(i.length>0?"af_id="+i:""),p.parentNode.insertBefore(o,p)}(window,document,"script",0,"AF","banners",{banners: {key: "5504562d-c8c0-4d00-b144-abec5282bb44"}})
#   AF('banners', 'showBanner')
#   }
#   </script> -->
# <script defer="">
#
#   if (window.innerWidth <= 720) {
#     (function (w, d, s, l, i) {
#       w[l] = w[l] || []; w[l].push({
#         'gtm.start': new Date().getTime(),
#         event: 'gtm.js'
#       });
#       var f = d.getElementsByTagName(s)[0],
#         j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.defer = true;
#       j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#     })(window, document, 'script', 'dataLayer', 'GTM-N92Z4HX');
#   } else {
#     (function (w, d, s, l, i) {
#       w[l] = w[l] || []; w[l].push({
#         'gtm.start': new Date().getTime(),
#         event: 'gtm.js'
#       });
#       var f = d.getElementsByTagName(s)[0],
#         j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.defer = true;
#       j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#     })(window, document, 'script', 'dataLayer', 'GTM-T5D99ZQ');
#   }
# </script>
# <!-- <script type="text/javascript" defer crossorigin >
#   window._mfq = window._mfq || [];
#   (function () {
#     var mf = document.createElement("script");
#     mf.type = "text/javascript"; mf.defer = true;
#     mf.src = "//cdn.mouseflow.com/projects/5b682ad1-e019-4731-80c4-d3703b7fd36d.js";
#     document.getElementsByTagName("head")[0].appendChild(mf);
#   })();
# </script> -->
# <script id="serverApp-state" type="application/json">{&q;G.json.https://www.pepperfry.com/homeapp-api/static-block/identifier/common-messages?&q;:{&q;body&q;:{&q;status&q;:{&q;status_code&q;:1,&q;status_message&q;:&q;Success&q;,&q;response_status&q;:&q;Success&q;,&q;response_code&q;:200},&q;data&q;:[{&q;additiondata&q;:&q;string&q;,&q;id&q;:&q;7817dfb6-f295-4467-967d-a44b076564b5&q;,&q;title&q;:&q;common-messages&q;,&q;identifier&q;:&q;common-messages&q;,&q;contentHTML&q;:&q;string&q;,&q;contentJSON&q;:{&q;app_url&q;:&q;&q;,&q;studioIconText&q;:{&q;studioIconFirstText&q;:&q;Find a&q;,&q;studioIconSecondText&q;:&q;Store&q;},&q;signupCreditText&q;:&q;Get Extra 10% Off&q;,&q;bopWhatsappMessage&q;:&q;Hi, I’d like to talk to someone about my Home and Furniture requirements. Thank you.&q;,&q;bopFormSubmitMessage&q;:&q;Our Dedicated Team will soon get in touch with you to understand your requirements and assist you further.&q;,&q;walkInStudioHeadingText&q;:&q;Find A Store Near You&q;,&q;walkInStudioSubHeadingText&q;:&q;Open All Week - 11 AM to 9 PM&q;},&q;metaTitle&q;:&q;string&q;,&q;metaKeyword&q;:&q;string&q;,&q;metaDescription&q;:&q;string&q;,&q;layout_id&q;:1,&q;status&q;:true,&q;validity_status&q;:true,&q;valid_from&q;:&q;2022-03-26T18:57:18.000Z&q;,&q;valid_to&q;:&q;2022-03-26T18:57:18.000Z&q;,&q;vg_homeapp_layout&q;:{&q;additiondata&q;:null,&q;id&q;:1,&q;name&q;:&q;testing&q;,&q;display_name&q;:&q;test&q;,&q;max_items&q;:0,&q;is_enabled&q;:true}}]},&q;headers&q;:{&q;date&q;:[&q;Tue, 27 Feb 2024 08:50:50 GMT&q;],&q;content-type&q;:[&q;application/json; charset=utf-8&q;],&q;content-length&q;:[&q;1084&q;],&q;connection&q;:[&q;keep-alive&q;],&q;vary&q;:[&q;Accept-Encoding&q;],&q;cache-control&q;:[&q;private, no-cache, no-store, must-revalidate&q;],&q;expires&q;:[&q;-1&q;],&q;pragma&q;:[&q;no-cache&q;],&q;x-content-type-options&q;:[&q;nosniff&q;],&q;x-frame-options&q;:[&q;SAMEORIGIN&q;],&q;x-xss-protection&q;:[&q;1; mode=block&q;],&q;strict-transport-security&q;:[&q;max-age=2592000&q;],&q;link&q;:[&q;&l;https://ii1.pepperfry.com&g;;rel=\&q;preconnect\&q;, &l;https://ii2.pepperfry.com&g;;rel=\&q;preconnect\&q;, &l;https://ii3.pepperfry.com&g;;rel=\&q;preconnect\&q;, &l;https://j1.pepperfry.com&g;;rel=\&q;preconnect\&q;&q;]},&q;status&q;:200,&q;statusText&q;:&q;OK&q;,&q;url&q;:&q;https://www.pepperfry.com/homeapp-api/static-block/identifier/common-messages&q;,&q;responseType&q;:&q;json&q;},&q;HEADER_STATIC_BLOCK&q;:{&q;status&q;:200,&q;data&q;:{&q;additiondata&q;:&q;additiondata test&q;,&q;id&q;:&q;16e7025c-92af-4cd2-a6e5-3c821e9f2f83&q;,&q;title&q;:&q;test2&q;,&q;identifier&q;:&q;header_ticker&q;,&q;contentHTML&q;:&q;html&q;,&q;contentJSON&q;:{&q;app_url&q;:&q;&q;,&q;mobilePromoTicker&q;:{&q;offerCode&q;:&q;EOSS&q;,&q;promoSaleTxt&q;:&q;Get Upto 75% Off &a; 20% Cashback On All Purchases&q;,&q;promoCloseTxt&q;:&q;Free Shipping On Everything&q;},&q;webCarouselTicker&q;:[{&q;saleText&q;:&q;Additional Discount&q;,&q;cashbackText&q;:&q;Upto Rs. 10,000/-&q;,&q;bankofferText&q;:&q;  Available at Your Nearest Store&q;},{&q;saleText&q;:&q;Additional Discount&q;,&q;cashbackText&q;:&q;Upto Rs.2,000/-&q;,&q;bankofferText&q;:&q;ICICI Bank, IDFC Bank &a; More&q;},{&q;saleText&q;:&q;No Cost &q;,&q;cashbackText&q;:&q;EMI Offers &q;,&q;bankofferText&q;:&q;  Available With All Leading Banks&q;}]},&q;metaTitle&q;:&q;metaTitle test&q;,&q;metaKeyword&q;:&q;metaKeyword test&q;,&q;metaDescription&q;:&q;metaDescription test&q;,&q;layout_id&q;:1,&q;status&q;:true,&q;validity_status&q;:true,&q;valid_from&q;:&q;2022-03-28T10:38:08.084Z&q;,&q;valid_to&q;:&q;2022-03-28T10:38:08.084Z&q;,&q;vg_homeapp_layout&q;:{&q;additiondata&q;:null,&q;id&q;:1,&q;name&q;:&q;testing&q;,&q;display_name&q;:&q;test&q;,&q;max_items&q;:0,&q;is_enabled&q;:true}}},&q;G.json.https://www.pepperfry.com/homeapp-api/static-block/16e7025c-92af-4cd2-a6e5-3c821e9f2f83?&q;:{&q;body&q;:{&q;status&q;:200,&q;data&q;:{&q;additiondata&q;:&q;additiondata test&q;,&q;id&q;:&q;16e7025c-92af-4cd2-a6e5-3 ...

# %%
first=soup.find_all('pf-clip-product-card')

# %%
for i in range(8):
    print(first[i].div.a.attrs['href'])
    print(i)
# Out:
# /product/cove-solid-wood-sideboard-in-irish-walnut-colour-2163467.html?type=search&pos=1&total_result=62&sort=sorting_score%7Cdesc&filter=%7C&search=book-cases
# 0
# /product/ashoka-sheesham-wood-2-door-bookshelf-in-brown-colour-2153021.html?type=search&pos=2&total_result=62&sort=sorting_score%7Cdesc&filter=%7C&search=book-cases
# 1
# /product/reverie-3-door-book-case-in-brown-colour-2164112.html?type=search&pos=3&total_result=62&sort=sorting_score%7Cdesc&filter=%7C&search=book-cases
# 2
# /product/reverie-2-door-book-case-in-brown-colour-2164111.html?type=search&pos=4&total_result=62&sort=sorting_score%7Cdesc&filter=%7C&search=book-cases
# 3
# /product/evoke-3-door-book-case-in-brown-colour-2164110.html?type=search&pos=5&total_result=62&sort=sorting_score%7Cdesc&filter=%7C&search=book-cases
# 4
# /product/evoke-2-door-book-case-in-brown-colour-2164109.html?type=search&pos=6&total_result=62&sort=sorting_score%7Cdesc&filter=%7C&search=book-cases
# 5
# /product/sleek-book-case-in-lyon-teak-white-finish-2154947.html?type=search&pos=7&total_result=62&sort=sorting_score%7Cdesc&filter=%7C&search=book-cases
# 6
# /product/sleek-book-case-in-dark-wenge-finish-2154946.html?type=search&pos=8&total_result=62&sort=sorting_score%7Cdesc&filter=%7C&search=book-cases
# 7

# %%
first[1].div.a.attrs['href']
# Out:
# '/product/ashoka-sheesham-wood-2-door-bookshelf-in-brown-colour-2153021.html?type=search&pos=2&total_result=62&sort=sorting_score%7Cdesc&filter=%7C&search=book-cases'

# %%
# id[24].attrs['href']

# %%
for i in range(24,33):
    print(id[i].attrs['href'])
# Out:
# /product/cove-solid-wood-sideboard-in-irish-walnut-colour-2163467.html?type=search&pos=1&total_result=62&sort=sorting_score%7Cdesc&filter=%7C&search=book-cases
# /product/ashoka-sheesham-wood-2-door-bookshelf-in-brown-colour-2153021.html?type=search&pos=2&total_result=62&sort=sorting_score%7Cdesc&filter=%7C&search=book-cases
# /product/reverie-3-door-book-case-in-brown-colour-2164112.html?type=search&pos=3&total_result=62&sort=sorting_score%7Cdesc&filter=%7C&search=book-cases
# /product/reverie-2-door-book-case-in-brown-colour-2164111.html?type=search&pos=4&total_result=62&sort=sorting_score%7Cdesc&filter=%7C&search=book-cases
# /product/evoke-3-door-book-case-in-brown-colour-2164110.html?type=search&pos=5&total_result=62&sort=sorting_score%7Cdesc&filter=%7C&search=book-cases
# /product/evoke-2-door-book-case-in-brown-colour-2164109.html?type=search&pos=6&total_result=62&sort=sorting_score%7Cdesc&filter=%7C&search=book-cases
# /product/sleek-book-case-in-lyon-teak-white-finish-2154947.html?type=search&pos=7&total_result=62&sort=sorting_score%7Cdesc&filter=%7C&search=book-cases
# /product/sleek-book-case-in-dark-wenge-finish-2154946.html?type=search&pos=8&total_result=62&sort=sorting_score%7Cdesc&filter=%7C&search=book-cases
# /site_product/search?page=1&q=book-cases

# %%
product=first[1].div.a.attrs['href']

# %%
url=f'https://www.pepperfry.com{product}'

# %%
url
# Out:
# 'https://www.pepperfry.com/product/ashoka-sheesham-wood-2-door-bookshelf-in-brown-colour-2153021.html?type=search&pos=2&total_result=62&sort=sorting_score%7Cdesc&filter=%7C&search=book-cases'

# %%
response=requests.get(url,headers=headers)

# %%
response
# Out:
# <Response [200]>

# %%
soup=bs4.BeautifulSoup(response.content)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <meta charset="utf-8"/>
# <meta content="”no-cache,no-store,must-revalidate”" http-equiv="”Cache-Control”"/>
# <meta content="”no-cache”" http-equiv="”Pragma”"/>
# <meta content='”0"' http-equiv="”Expires”"/>
# <meta content="noodp, noydir" name="robots"/>
# <title>Buy Ashoka Sheesham Wood 2 Door Book Case in Brown Colour at 54% OFF by Royaloak | Pepperfry</title>
# <base href="/"/>
# <meta content="user-scalable=no, width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <link href="favicon.ico" rel="icon" type="image/x-icon"/>
# <!-- <script src="https://js.appboycdn.com/web-sdk/4.5/service-worker.js"></script> -->
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
# <link crossorigin="" href="https://ii1.pepperfry.com" rel="preconnect"/>
# <link crossorigin="" href="https://ii2.pepperfry.com" rel="preconnect"/>
# <link crossorigin="" href="https://ii3.pepperfry.com" rel="preconnect"/>
# <link crossorigin="" href="https://cw.pepperfry.com" rel="preconnect"/>
# <!-- Preloading Important Icons -->
# <link as="image" href="https://ii1.pepperfry.com/assets/w22-pf-logo.svg" rel="preload"/>
# <link as="image" href="https://ii2.pepperfry.com/assets/w22-pf-wishlist-icon.svg" rel="preload"/>
# <link as="image" href="https://ii1.pepperfry.com/assets/w22-pf-cart-icon.svg" rel="preload"/>
# <link as="image" href="https://ii2.pepperfry.com/assets/w22-search-icon.svg" rel="preload"/>
# <link as="image" href="https://ii3.pepperfry.com/assets/w38-pf-logo-mobile.svg" rel="preload"/>
# <link as="image" href=" https://ii1.pepperfry.com/media/wysiwyg/banners/w23-buy-on-phone-icon-1x.gif" rel="preload"/>
# <link as="image" href="https://ii1.pepperfry.com/assets/w-23-chat-bot.gif" rel="preload"/>
# <meta content="8C9BCDC3424062BDDA2B4F617B1E81D4" name="msvalidate.01"/>
# <!-- GA Script for Analytics-->
# <script async="" src="https://cdn.segment.com/analytics.js/v1/bnox7jexPU74jBHFxPWROoNEjczz2XS1/analytics.min.js" type="text/javascript"></script><script async="true">
#     if (window.innerWidth <= 720) {
#       (function (w, d, s, l, i) {
#         w[l] = w[l] || []; w[l].push({
#           'gtm.start':
#             new Date().getTime(), event: 'gtm.js'
#         }); var f = d.getElementsByTagName(s)[0],
#           j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#             'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#       })(window, document, 'script', 'dataLayer', 'GTM-K8V3Z8');
#
#     } else {
#
#       (function (w, d, s, l, i) {
#         w[l] = w[l] || []; w[l].push({
#           'gtm.start':
#             new Date().getTime(), event: 'gtm.js'
#         }); var f = d.getElementsByTagName(s)[0],
#           j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#             'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#       })(window, document, 'script', 'dataLayer', 'GTM-TWGMR3');
#     }
#   </script>
# <!-- Google map dynamic inline script -->
# <script>
#     (g => { var h, a, k, p = "The Google Maps JavaScript API", c = "google", l = "importLibrary", q = "__ib__", m = document, b = window; b = b[c] || (b[c] = {}); var d = b.maps || (b.maps = {}), r = new Set, e = new URLSearchParams, u = () => h || (h = new Promise(async (f, n) => { await (a = m.createElement("script")); e.set("libraries", [...r] + ""); for (k in g) e.set(k.replace(/[A-Z]/g, t => "_" + t[0].toLowerCase()), g[k]); e.set("callback", c + ".maps." + q); a.src = `https://maps.${c}apis.com/maps/api/js?` + e; d[q] = f; a.onerror = () => h = n(Error(p + " could not load.")); a.nonce = m.querySelector("script[nonce]")?.nonce || ""; m.head.append(a) })); d[l] ? console.warn(p + " only loads once. Ignoring:", g) : d[l] = (f, ...n) => r.add(f) && u().then(() => d[l](f, ...n)) })({
#       key: "AIzaSyDlKneuC_IiviXS3CMCw7KZhyxsoQc9tRM",
#       v: "quarterly",
#     });
#   </script>
# <!-- Google optimization-->
# <script defer="" src="https://www.googleoptimize.com/optimize.js?id=OPT-PFLLRR3"></script>
# <!-- Bing Script-->
# <script defer="" type="text/javascript">
#     (function (w, d, t, r, u) { var f, n, i; w[u] = w[u] || [], f = function () { var o = { ti: "5153102" }; o.q = w[u], w[u] = new UET(o), w[u].push("pageLoad") }, n = d.createElement(t), n.src = r, n.defer = 1, n.onload = n.onreadystatechange = function () { var s = this.readyState; s && s !== "loaded" && s !== "complete" || (f(), n.onload = n.onreadystatechange = null) }, i = d.getElementsByTagName(t)[0], i.parentNode.insertBefore(n, i) })(window, document, "script", "//bat.bing.com/bat.js", "uetq");
#   </script>
# <!-- <script src="https://cdn.trackjs.com/agent/v3/latest/t.js" crossorigin></script> -->
# <!-- <script defer crossorigin  async="true"
#  src="https://maps.googleapis.com/maps/api/js?v=3.exp&key=AIzaSyDlKneuC_IiviXS3CMCw7KZhyxsoQc9tRM&libraries=places&radius=50">
# </script> -->
# <!-- <script >
#   if (location.host.indexOf("localhost") !== 0) {
#     window.TrackJS && TrackJS.install({
#       token: "6a4e5a0b5e284d5d8332431f7048d8a9",
#       application: "pepperfry-fe-prod",
#     });
#   }
# </script> -->
# <!-- Start VWO Async SmartCode -->
# <link href="https://dev.visualwebsiteoptimizer.com" rel="preconnect"/>
# <script id="vwoCode" type="text/javascript">
# window._vwo_code || (function() {
# var account_id=788314,
# version=2.0,
# settings_tolerance=2000,
# hide_element='body',
# hide_element_style = 'opacity:0 !important;filter:alpha(opacity=0) !important;background:none !important',
# /* DO NOT EDIT BELOW THIS LINE */
# f=false,w=window,d=document,v=d.querySelector('#vwoCode'),cK='_vwo_'+account_id+'_settings',cc={};try{var c=JSON.parse(localStorage.getItem('_vwo_'+account_id+'_config'));cc=c&&typeof c==='object'?c:{}}catch(e){}var stT=cc.stT==='session'?w.sessionStorage:w.localStorage;code={use_existing_jquery:function(){return typeof use_existing_jquery!=='undefined'?use_existing_jquery:undefined},library_tolerance:function(){return typeof library_tolerance!=='undefined'?library_tolerance:undefined},settings_tolerance:function(){return cc.sT||settings_tolerance},hide_element_style:function(){return'{'+(cc.hES||hide_element_style)+'}'},hide_element:function(){return typeof cc.hE==='string'?cc.hE:hide_element},getVersion:function(){return version},finish:function(){if(!f){f=true;var e=d.getElementById('_vis_opt_path_hides');if(e)e.parentNode.removeChild(e)}},finished:function(){return f},load:function(e){var t=this.getSettings(),n=d.createElement('script'),i=this;if(t){n.textContent=t;d.getElementsByTagName('head')[0].appendChild(n);if(!w.VWO||VWO.caE){stT.removeItem(cK);i.load(e)}}else{n.fetchPriority='high';n.src=e;n.type='text/javascript';n.onerror=function(){_vwo_code.finish()};d.getElementsByTagName('head')[0].appendChild(n)}},getSettings:function(){try{var e=stT.getItem(cK);if(!e){return}e=JSON.parse(e);if(Date.now()>e.e){stT.removeItem(cK);return}return e.s}catch(e){return}},init:function(){if(d.URL.indexOf('__vwo_disable__')>-1)return;var e=this.settings_tolerance();w._vwo_settings_timer=setTimeout(function(){_vwo_code.finish();stT.removeItem(cK)},e);var t=d.currentScript,n=d.createElement('style'),i=this.hide_element(),r=t&&!t.async&&i?i+this.hide_element_style():'',c=d.getElementsByTagName('head')[0];n.setAttribute('id','_vis_opt_path_hides');v&&n.setAttribute('nonce',v.nonce);n.setAttribute('type','text/css');if(n.styleSheet)n.styleSheet.cssText=r;else n.appendChild(d.createTextNode(r));c.appendChild(n);this.load('https://dev.visualwebsiteoptimizer.com/j.php?a='+account_id+'&u='+encodeURIComponent(d.URL)+'&vn='+version)}};w._vwo_code=code;code.init();})();
# </script>
# <!-- End VWO Async SmartCode -->
# <style>html{-webkit-text-size-adjust:100%}body{margin:0}@font-face{font-family:Manrope;font-style:normal;font-weight:200;font-display:swap;src:url(https://fonts.gstatic.com/s/manrope/v11/xn7gYHE41ni1AdIRggmxSuXd.woff2) format("woff2");unicode-range:U+0100-024F,U+0259,U+1E00-1EFF,U+2020,U+20A0-20AB,U+20AD-20CF,U+2113,U+2C60-2C7F,U+A720-A7FF}@font-face{font-family:Manrope;font-style:normal;font-weight:200;font-display:swap;src:url(https://fonts.gstatic.com/s/manrope/v11/xn7gYHE41ni1AdIRggexSg.woff2) format("woff2");unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+2000-206F,U+2074,U+20AC,U+2122,U+2191,U+2193,U+2212,U+2215,U+FEFF,U+FFFD}@font-face{font-family:Manrope;font-style:normal;font-weight:300;font-display:swap;src:url(https://fonts.gstatic.com/s/manrope/v11/xn7gYHE41ni1AdIRggmxSuXd.woff2) format("woff2");unicode-range:U+0100-024F,U+0259,U+1E00-1EFF,U+2020,U+20A0-20AB,U+20AD-20CF,U+2113,U+2C60-2C7F,U+A720-A7FF}@font-face{font-family:Manrope;font-style:normal;font-weight:300;font-display:swap;src:url(https://fonts.gstatic.com/s/manrope/v11/xn7gYHE41ni1AdIRggexSg.woff2) format("woff2");unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+2000-206F,U+2074,U+20AC,U+2122,U+2191,U+2193,U+2212,U+2215,U+FEFF,U+FFFD}@font-face{font-family:Manrope;font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/manrope/v11/xn7gYHE41ni1AdIRggmxSuXd.woff2) format("woff2");unicode-range:U+0100-024F,U+0259,U+1E00-1EFF,U+2020,U+20A0-20AB,U+20AD-20CF,U+2113,U+2C60-2C7F,U+A720-A7FF}@font-face{font-family:Manrope;font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/manrope/v11/xn7gYHE41ni1AdIRggexSg.woff2) format("woff2");unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+2000-206F,U+2074,U+20AC,U+2122,U+2191,U+2193,U+2212,U+2215,U+FEFF,U+FFFD}@font-face{font-family:Manrope;font-style:normal;font-weight:500;font-display:swap;src:url(https://fonts.gstatic.com/s/manrope/v11/xn7gYHE41ni1AdIRggmxSuXd.woff2) format("woff2");unicode-range:U+0100-024F,U+0259,U+1E00-1EFF,U+2020,U+20A0-20AB,U+20AD-20CF,U+2113,U+2C60-2C7F,U+A720-A7FF}@font-face{font-family:Manrope;font-style:normal;font-weight:500;font-display:swap;src:url(https://fonts.gstatic.com/s/manrope/v11/xn7gYHE41ni1AdIRggexSg.woff2) format("woff2");unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+2000-206F,U+2074,U+20AC,U+2122,U+2191,U+2193,U+2212,U+2215,U+FEFF,U+FFFD}@font-face{font-family:Manrope;font-style:normal;font-weight:600;font-display:swap;src:url(https://fonts.gstatic.com/s/manrope/v11/xn7gYHE41ni1AdIRggmxSuXd.woff2) format("woff2");unicode-range:U+0100-024F,U+0259,U+1E00-1EFF,U+2020,U+20A0-20AB,U+20AD-20CF,U+2113,U+2C60-2C7F,U+A720-A7FF}@font-face{font-family:Manrope;font-style:normal;font-weight:600;font-display:swap;src:url(https://fonts.gstatic.com/s/manrope/v11/xn7gYHE41ni1AdIRggexSg.woff2) format("woff2");unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+2000-206F,U+2074,U+20AC,U+2122,U+2191,U+2193,U+2212,U+2215,U+FEFF,U+FFFD}@font-face{font-family:Manrope;font-style:normal;font-weight:700;font-display:swap;src:url(https://fonts.gstatic.com/s/manrope/v11/xn7gYHE41ni1AdIRggmxSuXd.woff2) format("woff2");unicode-range:U+0100-024F,U+0259,U+1E00-1EFF,U+2020,U+20A0-20AB,U+20AD-20CF,U+2113,U+2C60-2C7F,U+A720-A7FF}@font-face{font-family:Manrope;font-style:normal;font-weight:700;font-display:swap;src:url(https://fonts.gstatic.com/s/manrope/v11/xn7gYHE41ni1AdIRggexSg.woff2) format("woff2");unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+2000-206F,U+2074,U+20AC,U+2122,U+2191,U+2193,U+2212,U+2215,U+FEFF,U+FFFD}@font-face{font-family:Manrope;font-style:normal;font-weight:800;font-display:swap;src:url(https://fonts.gstatic.com/s/manrope/v11/xn7gYHE41ni1AdIRggmxSuXd.woff2) format("woff2");unicode-range:U+0100-024F,U+0259,U+1E00-1EFF,U+2020,U+20A0-20AB,U+20A ...
# </style><style ng-transition="serverApp">.bop-widget-screen-content[_ngcontent-sc176]{display:flex;flex-direction:column;align-items:center}.bop-widget-screen-content[_ngcontent-sc176]   .bop-widget-screen-line-1[_ngcontent-sc176]{margin-top:12px}.bop-widget-screen-content[_ngcontent-sc176]   .bop-widget-screen-line-1[_ngcontent-sc176]   .bop-widget-dot-icon[_ngcontent-sc176]{margin-right:4px}.bop-widget-screen-content[_ngcontent-sc176]   .bop-widget-screen-line-2[_ngcontent-sc176]{display:flex;flex-direction:column;align-items:center}.bop-widget-screen-content[_ngcontent-sc176]   .expert-available-timing-section[_ngcontent-sc176]{color:#848484}.bop-widget-screen-content[_ngcontent-sc176]   .bop-widget-screen-line-3[_ngcontent-sc176]{display:flex;justify-content:center;align-items:center}.bop-widget-screen-content[_ngcontent-sc176]   .bop-widget-screen-line-3[_ngcontent-sc176]   .bop-caller-icon[_ngcontent-sc176]{display:flex;margin-right:2px}.bop-widget-screen-content[_ngcontent-sc176]   .divider[_ngcontent-sc176]{display:flex;align-items:center;width:100%}.bop-widget-screen-content[_ngcontent-sc176]   .divider[_ngcontent-sc176]:before, .bop-widget-screen-content[_ngcontent-sc176]   .divider[_ngcontent-sc176]:after{content:"";flex:1;border-bottom:1px solid #E0E0E0;margin:0 8px}  .button-container span{margin-right:4px}.bop-widget-random-expert-text[_ngcontent-sc176]{color:#67ad5b}@keyframes blink{0%{opacity:1}50%{opacity:0}to{opacity:1}}.blink[_ngcontent-sc176]{animation:blink 1s infinite}</style><style ng-transition="serverApp">.button-container{font-size:.875rem;line-height:1.375rem;padding:12px 16px;color:#fff;transition:all .3s ease-in;cursor:pointer;font-weight:700;border-radius:2px;border:none;background:transparent}@media only screen and (min-width : 1024px){.button-container{font-size:1rem;padding:12px 16px}}.button-block{width:100%}.button-primary{background-image:linear-gradient(180deg,rgba(246,77,24,.99) 0%,#FF7035 100%)}.button-primary:hover{background-color:#ff8d5d;background-image:linear-gradient(180deg,#FF8D5D 0%,#FF8D5D 100%)}.button-secondary{background-color:#1979b5;background-image:none}.button-success{background-color:#85bd7c;background-image:none}.button-info{background-color:#4794c4;background-image:none}.button-warning{background-color:#f69a23;background-image:none}.button-link{background-color:#ff7035}.button-rounded{border-radius:50px}.button-solid{color:#fff;border:none}.button-outline{border:solid 1px #E0E0E0;color:#5b5b5b}.button-outline:hover{background-color:#f5f5f5}.button-outline-orange{border:solid 1px #FF7035;color:#ff7035}.button-outline-orange:hover{background-color:#ffe2d7}.button-dashed{border:dashed 1px #FF7035;color:#ff7035}.button-size--large{padding:12px 16px;font-size:.875rem;line-height:1.25rem}@media only screen and (min-width : 1280px){.button-size--large{font-size:1rem;line-height:1.5rem}}.button-size--base{padding:10px 32px;font-size:.875rem;line-height:1.25rem}.button-size--medium{padding:8px 16px;font-size:.875rem;line-height:1.25rem}@media only screen and (min-width : 1280px){.button-size--medium{font-size:1rem;line-height:1.5rem}}.button-size--small{padding:8px 16px;font-size:.625rem;line-height:1rem}@media only screen and (min-width : 768px){.button-size--small{font-size:.75rem;line-height:1.25rem}}@media only screen and (min-width : 1280px){.button-size--small{font-size:.875rem;line-height:1.5rem}}.button-default{width:100%}.button-icon{width:46px;height:46px}[disabled]{background-color:#e0e0e0;background-image:none;cursor:default;pointer-events:none}.button-text-large,.button-text-medium,.button-text-small{color:#ff7035}.button-text-large,.button-text-medium{font-size:.875rem;line-height:1.25rem;font-weight:700}@media only screen and (min-width : 1280px){.button-text-large,.button-text-medium{font-size:1rem;line-height:1.5rem}}.button-text-small{font-size:.625rem;line-height:1rem;font-weight:700}@media only screen and (min-width : 768px){.button-text-small{font-size:.75re ...
# </style><style ng-transition="serverApp">.header-main-section[_ngcontent-sc175]{position:relative;background-color:#fff;width:100%}@media only screen and (max-width : 1023px){.header-main-section[_ngcontent-sc175]{border-bottom:1px solid #F5F5F5}}@media only screen and (min-width : 1024px){.main-header[_ngcontent-sc175]{min-height:152px}}@media only screen and (min-width : 768px) and (max-width : 1023px){.main-header[_ngcontent-sc175]{min-height:61px}}@media only screen and (max-width : 767px){.main-header[_ngcontent-sc175]{min-height:0}}@media only screen and (min-width : 1024px){.zIndex[_ngcontent-sc175]{z-index:901}}.ctg-header-main-section[_ngcontent-sc175]{z-index:980;top:0;position:fixed}#menuTransOverlay[_ngcontent-sc175]{position:fixed;width:100%;height:100%;z-index:700;left:0;top:0;display:none;background-color:#00000042}#menuTransOverlay.active[_ngcontent-sc175]{display:block}@media only screen and (max-width : 767px){#menuTransOverlay.active[_ngcontent-sc175]{display:none}}</style><style ng-transition="serverApp">.hd-promo-wrap[_ngcontent-sc170]{background:#121212;color:#fff;padding:10px 0}@media only screen and (max-width : 767px){.hd-promo-wrap[_ngcontent-sc170]{padding:5px 0}}.hd-mobile-promo-banner[_ngcontent-sc170]{height:55px;display:flex;align-items:center;overflow:hidden}.hd-mobile-promo-banner[_ngcontent-sc170]   .hd-mobile-promo-text[_ngcontent-sc170]{width:calc(100% - 48px);color:#fff;padding:4px 4px 4px 16px}.hd-mobile-promo-banner[_ngcontent-sc170]   .hd-mobile-promo-text[_ngcontent-sc170]   .hd-mobile-offer-sale[_ngcontent-sc170]{display:block}.hd-mobile-promo-banner[_ngcontent-sc170]   .hd-mobile-close-section[_ngcontent-sc170]{width:48px;height:56px;display:flex;align-items:center;justify-content:center}.hd-mobile-promo-banner[_ngcontent-sc170]   .hd-mobile-close-section[_ngcontent-sc170]   img[_ngcontent-sc170]{width:auto;height:auto;max-width:100%}@media only screen and (min-width : 768px){.hd-mobile-promo-banner[_ngcontent-sc170]{display:none}}</style><style ng-transition="serverApp">#signup-sucess-popup-overlay-wrap[_ngcontent-sc174]{position:fixed;width:100%;height:100%;inset:0;background-color:#00000080;z-index:10000;cursor:pointer;-webkit-tap-highlight-color:transparent}.success-popup-content-wrap[_ngcontent-sc174]{position:fixed;top:50%;left:50%;transform:translate(-50%,-50%)}.wap-content[_ngcontent-sc174]{width:328px;height:173px}.web-content[_ngcontent-sc174]{width:417px;height:616px}.success-popup-content[_ngcontent-sc174]{display:inline-block;position:relative;cursor:default}.success-popup-content[_ngcontent-sc174]   .close-wrapper[_ngcontent-sc174]{position:absolute;width:24px;height:24px;top:11px;right:15px;cursor:pointer}.success-popup-content[_ngcontent-sc174]   .close-wrapper-wap[_ngcontent-sc174]{position:absolute;width:24px;height:24px;top:4px;right:14px;cursor:pointer}</style><style ng-transition="serverApp">[_nghost-sc158]{--footer-bottom: 20px}footer[_ngcontent-sc158]{width:100%}footer[_ngcontent-sc158]   .footer-wrapper[_ngcontent-sc158]{background-color:#f5f5f5}@media only screen and (max-width : 767px){footer[_ngcontent-sc158]   .footer-margin-bottom[_ngcontent-sc158]{margin-bottom:69px}}footer[_ngcontent-sc158]   .row[_ngcontent-sc158]{display:flex;justify-content:space-between}footer[_ngcontent-sc158]   .row[_ngcontent-sc158]   .footer-col[_ngcontent-sc158]{width:18%}footer[_ngcontent-sc158]   .row[_ngcontent-sc158]   .footer-col[_ngcontent-sc158]   p[_ngcontent-sc158]{margin:0 0 8px}footer[_ngcontent-sc158]   .ul-flex[_ngcontent-sc158]{display:flex;flex-direction:column}footer[_ngcontent-sc158]   .store-images-wrapper[_ngcontent-sc158]{align-items:center}footer[_ngcontent-sc158]   .second-row-section[_ngcontent-sc158]{padding:80px 0 40px}@media only screen and (min-width : 768px){footer[_ngcontent-sc158]   .second-row-section[_ngcontent-sc158]   .footer-col[_ngcontent-sc158]{width:30%}}footer[_ngcontent-sc158]   li[_ngcontent-sc158]{list-style-type:none;display:inline-bloc ...
# </style><style ng-transition="serverApp">@media only screen and (min-width : 768px){[_nghost-sc156]  .card-icons .picture-image-cls-container img{width:44px}}@media only screen and (min-width : 1024px){[_nghost-sc156]  .card-icons .picture-image-cls-container img{width:56px}}@media only screen and (min-width : 1280px){[_nghost-sc156]  .card-icons .picture-image-cls-container img{width:76px}}.accept-cards[_ngcontent-sc156]   .accept-header[_ngcontent-sc156]{margin-top:0}@media only screen and (max-width : 767px){.accept-cards[_ngcontent-sc156]   .accept-header[_ngcontent-sc156]{margin-top:28px}}.accept-card-icons[_ngcontent-sc156]{display:flex;flex-direction:row;flex:1}@media only screen and (max-width : 767px){.accept-card-icons[_ngcontent-sc156]{margin-bottom:28px}}.accept-card-icons[_ngcontent-sc156]   .accept-card-icon[_ngcontent-sc156]{margin-right:4px}</style><style ng-transition="serverApp">.social-icon-wrapper[_ngcontent-sc157]{display:flex;width:100%;justify-content:center}@media only screen and (min-width : 768px){.social-icon-section[_ngcontent-sc157]{margin:0}}.social-icon-heading[_ngcontent-sc157]{margin:20px auto 8px}@media only screen and (min-width : 768px){.social-icon-heading[_ngcontent-sc157]{margin-top:0}}[_nghost-sc157]  .social-icons .picture-image-container img{width:28px;height:28px;margin-right:12px}@media only screen and (min-width : 1024px){[_nghost-sc157]  .social-icons .picture-image-container img{width:32px;height:32px;margin-right:20px}}@media only screen and (min-width : 1280px){[_nghost-sc157]  .social-icons .picture-image-container img{width:46px;height:46px}}</style><style ng-transition="serverApp">.legal-pages-section[_ngcontent-sc155]{justify-content:center}@media only screen and (max-width : 767px){.legal-pages-section[_ngcontent-sc155]{justify-content:flex-start}}@media only screen and (min-width : 768px){.legal-pages-section[_ngcontent-sc155]   a[_ngcontent-sc155]{padding-right:12px}}@media only screen and (min-width : 1024px){.legal-pages-section[_ngcontent-sc155]   a[_ngcontent-sc155]{padding-right:20px}}.legal-pages-section[_ngcontent-sc155]   .legal-pages-mobile[_ngcontent-sc155]   span[_ngcontent-sc155]{padding:0 4px}</style><style ng-transition="serverApp">.vip-page-container[_ngcontent-sc237]   .img-dim-tag[_ngcontent-sc237]{width:auto;height:auto;max-width:100%}.vip-page-container[_ngcontent-sc237]   .vip-sticky-header[_ngcontent-sc237]{display:none}@media only screen and (min-width : 768px){.vip-page-container[_ngcontent-sc237]   .vip-sticky-header[_ngcontent-sc237]{display:block;z-index:99;position:fixed;padding:12px;top:-100vh;background-color:#fff;box-shadow:0 4px 5px #0000000a;width:100%;transition:top .3s}.vip-page-container[_ngcontent-sc237]   .vip-sticky-header[_ngcontent-sc237]   .vip-sticky-back-link-wrap[_ngcontent-sc237]{cursor:pointer}.vip-page-container[_ngcontent-sc237]   .vip-sticky-header[_ngcontent-sc237]   .vip-sticky-header-icon[_ngcontent-sc237]{margin-right:8px;cursor:pointer;width:24px;height:24px;display:inline-block;border:1px solid #E0E0E0}.vip-page-container[_ngcontent-sc237]   .vip-sticky-header[_ngcontent-sc237]   .vip-sticky-header-icon[_ngcontent-sc237]   img[_ngcontent-sc237]{filter:brightness(0) saturate(100%) invert(60%) sepia(0%) saturate(314%) hue-rotate(176deg) brightness(87%) contrast(85%)}.vip-page-container[_ngcontent-sc237]   .vip-sticky-header[_ngcontent-sc237]   .vip-stickyheader-ttl[_ngcontent-sc237]{display:inline-block}}.vip-page-container[_ngcontent-sc237]   .mobile-solid-border-bottom-white[_ngcontent-sc237]{border-bottom:16px solid white!important}.vip-page-container[_ngcontent-sc237]   .mobile-solid-border-top-gray[_ngcontent-sc237]{border-top:8px solid #F5F5F5}.vip-page-container[_ngcontent-sc237]   .web-solid-border-bottom-gray[_ngcontent-sc237]{border-bottom:2px solid #E0E0E0}.vip-page-container[_ngcontent-sc237]   .vip-page-section[_ngcontent-sc237]{padding:12px 0;border-bottom:8px solid #F5F5F5}@media only screen and (min-widt ...
# </style><style ng-transition="serverApp">.marginRight-4[_ngcontent-sc213]{margin-right:4px}.img-dim-tag[_ngcontent-sc213]{width:auto;height:auto;max-width:100%}@media only screen and (min-width : 768px){#vip-img-gallery-container[_ngcontent-sc213]{position:sticky;top:0;z-index:16}}@media only screen and (max-width : 767px){#vip-img-gallery-container[_ngcontent-sc213]   .web-vip-img-gallery-container[_ngcontent-sc213]{display:none}}#vip-img-gallery-container[_ngcontent-sc213]   .web-vip-img-gallery-container[_ngcontent-sc213]   .web-vip-3d[_ngcontent-sc213]{position:absolute;z-index:4;top:0;left:0;height:100%;width:100%;background-color:#f5f5f5;overflow:hidden}#vip-img-gallery-container[_ngcontent-sc213]   .web-vip-img-gallery-container[_ngcontent-sc213]   .magnifyLens[_ngcontent-sc213]{position:absolute;left:0;top:0;border:1px solid #121212;background-color:#ffffff4d;cursor:crosshair;display:none}#vip-img-gallery-container[_ngcontent-sc213]   .web-vip-img-gallery-container[_ngcontent-sc213]   .web-vip-magnified-container[_ngcontent-sc213]{position:absolute;top:0;overflow:hidden;height:579px;display:none;box-shadow:0 4px 20px 2px #0003;background-color:#f5f5f5;max-height:100vh}#vip-img-gallery-container[_ngcontent-sc213]   .web-vip-img-gallery-container[_ngcontent-sc213]   .web-vip-magnified-container[_ngcontent-sc213]   img[_ngcontent-sc213]{max-width:initial;position:relative}#vip-img-gallery-container[_ngcontent-sc213]   .wap-vip-img-gallery-container[_ngcontent-sc213]{margin-left:-8px;margin-right:-8px}@media only screen and (min-width : 768px){#vip-img-gallery-container[_ngcontent-sc213]   .wap-vip-img-gallery-container[_ngcontent-sc213]{display:none}}#vip-img-gallery-container[_ngcontent-sc213]   .wap-vip-img-gallery-container[_ngcontent-sc213]   .wap-vip-img-gallery-wrapper[_ngcontent-sc213]{position:relative;background-color:#f5f5f5}#vip-img-gallery-container[_ngcontent-sc213]   .wap-vip-img-gallery-container[_ngcontent-sc213]   .wap-vip-feature-tag[_ngcontent-sc213]{z-index:2;padding:4px}#vip-img-gallery-container[_ngcontent-sc213]   .wap-vip-img-gallery-container[_ngcontent-sc213]   .wap-vip-similar-itms[_ngcontent-sc213]{position:absolute;left:12px;bottom:10px}#vip-img-gallery-container[_ngcontent-sc213]   .wap-vip-img-gallery-container[_ngcontent-sc213]   .wap-vip-similar-set-row[_ngcontent-sc213]{z-index:2}#vip-img-gallery-container[_ngcontent-sc213]   .wap-vip-img-gallery-container[_ngcontent-sc213]   .wap-vip-wishlist[_ngcontent-sc213]{position:absolute;right:12px;bottom:-12px;z-index:2}#vip-img-gallery-container[_ngcontent-sc213]   .wap-vip-img-gallery-container[_ngcontent-sc213]   .wap-vip-share[_ngcontent-sc213]{position:absolute;right:12px;bottom:40px;z-index:2}#vip-img-gallery-container[_ngcontent-sc213]   .wap-vip-img-gallery-container[_ngcontent-sc213]   .wap-3d-img-ico-wrapper[_ngcontent-sc213]{padding:8px 0;text-align:center;border-top:1px solid #EEEEEE;border-bottom:1px solid #EEEEEE;display:flex;justify-content:center;align-items:center;gap:2px}#vip-img-gallery-container[_ngcontent-sc213]   .web-vip-thumb-main-wrapper[_ngcontent-sc213]{position:relative}#vip-img-gallery-container[_ngcontent-sc213]   .web-vip-thumb-main-wrapper[_ngcontent-sc213]   .web-vip-thumb-gallery[_ngcontent-sc213]{width:54px;position:absolute;height:100%;overflow:hidden}#vip-img-gallery-container[_ngcontent-sc213]   .web-vip-thumb-main-wrapper[_ngcontent-sc213]   .web-vip-thumb-gallery[_ngcontent-sc213]   .web-vip-thumb-images[_ngcontent-sc213]{transition:all .3s ease-in-out 0s;cursor:pointer}@media only screen and (min-width : 1024px){#vip-img-gallery-container[_ngcontent-sc213]   .web-vip-thumb-main-wrapper[_ngcontent-sc213]   .web-vip-thumb-gallery[_ngcontent-sc213]{width:69px}}@media only screen and (min-width : 1280px){#vip-img-gallery-container[_ngcontent-sc213]   .web-vip-thumb-main-wrapper[_ngcontent-sc213]   .web-vip-thumb-gallery[_ngcontent-sc213]{width:91px}}#vip-img-gallery-container[_ngcontent-sc213]   .web-vip-thumb ...
# </style><style ng-transition="serverApp">[_nghost-sc223]  pf-accordion .accordion-container{margin:0;background-color:transparent}[_nghost-sc223]  pf-accordion .accordion-container .panel{border:none;border-bottom:1px solid #E0E0E0}@media only screen and (min-width : 768px){[_nghost-sc223]  pf-accordion .accordion-container .panel{border-bottom:2px solid #E0E0E0}}[_nghost-sc223]  pf-accordion .accordion-container .panel-heading .panel-title{padding:12px 0}[_nghost-sc223]  pf-accordion .accordion-container .panel-heading .panel-title:after{background-image:url(https://ii1.pepperfry.com/assets/w22-chevron-down-icon-24.svg);top:50%;transform:translateY(-50%);right:0;width:24px;height:24px}@media only screen and (max-width : 767px){[_nghost-sc223]  pf-accordion .accordion-container .panel-heading .panel-title:after{width:16px;height:16px}}@media only screen and (min-width : 768px){[_nghost-sc223]  pf-accordion .accordion-container .panel-heading .panel-title{padding:16px 0}}[_nghost-sc223]  pf-accordion .accordion-container .panel-heading .panel-title .vip-accordian-ttl{font-family:Manrope,sans-serif}[_nghost-sc223]  pf-accordion .accordion-container .dropup .panel-heading .panel-title:after{background-image:url(https://ii1.pepperfry.com/assets/w22-chevron-up-icon-24.svg)!important}[_nghost-sc223]  pf-accordion .accordion-container .panel-body{padding:0 0 12px}[_nghost-sc223]  pf-accordion .accordion-container .panel-body .accordian-body-wrap{color:#5b5b5b;word-wrap:break-word}[_nghost-sc223]  pf-accordion .accordion-container .panel-body .accordian-body-wrap ul li{margin-bottom:8px}[_nghost-sc223]  pf-accordion .accordion-container .panel-body .accordian-body-wrap ul li:last-child{margin-bottom:0}[_nghost-sc223]  pf-accordion .accordion-container .panel-body .accordian-body-wrap p{margin:0 0 8px;font-size:12px}@media only screen and (min-width : 768px){[_nghost-sc223]  pf-accordion .accordion-container .panel-body .accordian-body-wrap p{font-size:14px}}[_nghost-sc223]  pf-accordion .accordion-container .panel-body .accordian-body-wrap p ::last-child{margin:0}[_nghost-sc223]  pf-accordion .accordion-container .panel-body .accordian-body-wrap .accordian-body-scroll{max-height:417px}[_nghost-sc223]  pf-accordion .accordion-container .panel-body .accordian-body-wrap .accordian-body-scroll .custom-scroll{max-height:100%}[_nghost-sc223]  pf-accordion .accordion-container .panel-body .accordian-body-wrap .accordian-body-scroll .custom-scroll .accordian-body-int-scroll-wrap{padding-bottom:20px}[_nghost-sc223]  pf-accordion .accordion-container .panel-body .accordian-body-wrap .accordian-body-scroll .custom-scroll .accordian-body-int-scroll-wrap ul{padding-bottom:20px}[_nghost-sc223]  pf-accordion .accordion-container .panel-body .accordian-body-wrap .accordian-body-scroll:after{content:"";position:absolute;left:0;bottom:0;display:block;width:100%;height:48px;background:linear-gradient(180deg,rgba(250,250,250,0) 0%,#FAFAFA 100%)}[_nghost-sc223]  pf-accordion .accordion-container .warranty-title{color:#5b5b5b}[_nghost-sc223]  .warantty-scroll-attribute .ng-scroll-content{width:-webkit-fill-available;width:-moz-available;padding-right:20px}[_nghost-sc223]  .vip-brand-proposition-wrapper pf-image img{width:auto;height:60px;margin-bottom:8px;background-color:#fff}@media only screen and (min-width : 768px){[_nghost-sc223]  .vip-brand-proposition-wrapper pf-image img{height:40px}}@media only screen and (min-width : 1024px){[_nghost-sc223]  .vip-brand-proposition-wrapper pf-image img{height:60px}}@media only screen and (min-width : 1280px){[_nghost-sc223]  .vip-brand-proposition-wrapper pf-image img{height:96px}}</style><style ng-transition="serverApp">.accordion-container{border-radius:5px;background:#F5F5F5;overflow:hidden;margin:0 10px}.accordion-container .panel{border:1px solid #EEEEEE}.accordion-container .panel.dropup .panel-heading .panel-title:after{background:url(data:image/png;base64,...) no-repeat 0 0!important;background-size:cover! ...
# </style><style ng-transition="serverApp">.vip-cta-section-container[_ngcontent-sc229]   .no-wrap[_ngcontent-sc229]{flex-wrap:nowrap}.vip-cta-section-container[_ngcontent-sc229]   .vip-cta-cart-btn[_ngcontent-sc229]{flex:1 0 auto;margin-right:12px}@media only screen and (max-width : 767px){.vip-cta-section-container[_ngcontent-sc229]   .vip-cta-cart-btn[_ngcontent-sc229]{margin-right:0;text-align:center}.vip-cta-section-container[_ngcontent-sc229]   .vip-cta-cart-btn[_ngcontent-sc229]   .button-outline[_ngcontent-sc229]{background-image:none;color:#5b5b5b;border-color:transparent}}.vip-cta-section-container[_ngcontent-sc229]   .vip-cta-buy-now-btn[_ngcontent-sc229]{flex:1 0 auto}@media only screen and (max-width : 767px){.vip-cta-section-container[_ngcontent-sc229]   .vip-cta-buy-now-btn[_ngcontent-sc229]   .button-primary[_ngcontent-sc229]{border-radius:0;width:100%}}.vip-cta-section-container[_ngcontent-sc229]   .vip-cta-out-of-stock-btn[_ngcontent-sc229]{flex:1 0 auto}@media only screen and (max-width : 767px){.vip-cta-section-container[_ngcontent-sc229]   .vip-cta-out-of-stock-btn[_ngcontent-sc229]   .button-primary[_ngcontent-sc229]{border-radius:0;width:100%;text-transform:uppercase;height:100%}}.vip-cta-section-container[_ngcontent-sc229]   .button-container[_ngcontent-sc229]{width:100%}.add-to-cart-toast-container[_ngcontent-sc229]{display:flex;justify-content:center;align-items:center}.add-to-cart-toast-container[_ngcontent-sc229]   .toast-name[_ngcontent-sc229], .add-to-cart-toast-container[_ngcontent-sc229]   .cart-icon[_ngcontent-sc229]{margin-right:8px}[_nghost-sc229]  pf-button.addtocat-btn .button-container{background:#fff}[_nghost-sc229]  pf-button.addtocat-btn .button-outline{color:#ff7035}[_nghost-sc229]  .vip-action-cta{width:100%}[_nghost-sc229]  .vip-cta-buy-now-btn button{border:1px solid #FF7035}</style><style ng-transition="serverApp">.vip-bank-offers[_ngcontent-sc214]   .sub-heading[_ngcontent-sc214]{display:flex;align-items:center}.vip-bank-offers[_ngcontent-sc214]   .sub-heading[_ngcontent-sc214]   .timer-text[_ngcontent-sc214]{color:#848484;margin-right:8px}.vip-bank-offers[_ngcontent-sc214]   .sub-heading[_ngcontent-sc214]   .timer-icon[_ngcontent-sc214]{display:flex}.vip-bank-offers[_ngcontent-sc214]   .sub-heading[_ngcontent-sc214]   .timer-count[_ngcontent-sc214]{color:#e04f55;margin-left:8px}@media only screen and (max-width : 1023px){.vip-bank-offers[_ngcontent-sc214]   .sub-heading[_ngcontent-sc214]{flex-direction:column;align-items:flex-start}}.vip-bank-offers[_ngcontent-sc214]   .bank-offer-desc[_ngcontent-sc214]{border-bottom:1px dashed #EEEEEE}.vip-bank-offers[_ngcontent-sc214]   .bank-offer-desc[_ngcontent-sc214]   .offer-code-text[_ngcontent-sc214], .vip-bank-offers[_ngcontent-sc214]   .bank-offer-desc[_ngcontent-sc214]   .desc[_ngcontent-sc214]{color:#5b5b5b}.vip-bank-offers[_ngcontent-sc214]   .bank-offer-desc[_ngcontent-sc214]   .incremental-discount[_ngcontent-sc214]{color:#67ad5b}</style><style ng-transition="serverApp">.midnight-countdowner-container[_ngcontent-sc206]{color:#d8232a}.midnight-countdowner-container[_ngcontent-sc206]   img[_ngcontent-sc206]{width:auto;height:auto;max-width:100%}.midnight-countdowner-container[_ngcontent-sc206]   .timer-icon[_ngcontent-sc206]{margin-right:4px}.midnight-countdowner-container[_ngcontent-sc206]   .timer-icon[_ngcontent-sc206]   img[_ngcontent-sc206]{height:1em}</style></head>
# <body>
# <app-root _nghost-sc181="" ng-server-context="other" ng-version="14.3.0"><pf-header _ngcontent-sc181="" _nghost-sc175=""><header _ngcontent-sc175="" class="header-main-section zIndex"><div _ngcontent-sc175="" class="promo-header"><pf-header-promo _ngcontent-sc175="" _nghost-sc170=""><!-- --><!-- --><!-- --></pf-header-promo></div><div _ngcontent-sc175="" class=""><pf-header-main _ngcontent-sc175="" _nghost-sc169=""><div _ngcontent-sc169="" class="main-header-container"><nav _ngcontent-sc169="" class="header-corporate-links"><ul _ngcontent-sc169="" class="hd-list-container container"><li _ngcontent-sc169="" class="hd-list-item uppercase"><a _ngcontent-sc169="" class="text-sm" data-test="sellOnPepperfry" href="/form/partners-partnerwithus.html?partner=seller&amp;type=header" routerlink="/form/partners-partnerwithus.html">Sell on pepperfry</a><!-- --><!-- --></li><li _ngcontent-sc169="" class="hd-list-item uppercase"><a _ngcontent-sc169="" class="text-sm" data-test="franchise" href="/form/partners-franchisee.html?type=header" routerlink="/form/partners-franchisee.html">Become a franchisee</a><!-- --><!-- --></li><li _ngcontent-sc169="" class="hd-list-item uppercase"><a _ngcontent-sc169="" class="text-sm" data-test="bulkOrder" href="/form/partners-bulkorder.html?type=header" routerlink="/form/partners-bulkorder.html">Buy in Bulk</a><!-- --><!-- --></li><li _ngcontent-sc169="" class="hd-list-item uppercase"><a _ngcontent-sc169="" class="text-sm" data-test="giftCard" href="/form/pepperfry-gift-cards.html?type=header" routerlink="/form/pepperfry-gift-cards.html">GIFT CARDS</a><!-- --><!-- --></li><li _ngcontent-sc169="" class="hd-list-item uppercase"><a _ngcontent-sc169="" class="text-sm" data-test="designInspiration" href="https://www.pepperfry.com/pages/design_inspiration.html?type=header">GET INSPIRED</a></li><li _ngcontent-sc169="" class="hd-list-item uppercase"><a _ngcontent-sc169="" class="text-sm" data-test="trackOrder" href="https://www.pepperfry.com/customer/myorders">Track Your Order</a></li><li _ngcontent-sc169="" class="hd-list-item uppercase"><a _ngcontent-sc169="" class="text-sm" data-test="contactUs" href="https://www.pepperfry.com/customer/needhelp/contactus">Contact us</a></li></ul></nav><div _ngcontent-sc169="" class="container"><div _ngcontent-sc169="" class="hd-main-menu-container"><div _ngcontent-sc169="" class="hd-mobile-hamburger-responsive cursor-pointer"><a _ngcontent-sc169="" class="hd-hamburger-cta cursor-pointer" role="link"><img _ngcontent-sc169="" alt="hamburger icon" src="https://ii1.pepperfry.com/assets/w38-hamburger.svg"/></a></div><div _ngcontent-sc169="" appclickoutside="" class="header-search"><div _ngcontent-sc169="" class="hd-search-wrap"><div _ngcontent-sc169="" class="hd-search-bar"><input _ngcontent-sc169="" autocomplete="off" class="hd-search-bar-inpt text-md ng-untouched ng-pristine ng-valid" data-test="searchInput" id="search" maxlength="100" name="q" pf-whitespace-validate="" placeholder="Search" type="text" value=""/><button _ngcontent-sc169="" class="hd-search-btn" data-test="searchIcon" id="searchButton" type="button"><img _ngcontent-sc169="" alt="search-icon" height="14" src="https://ii1.pepperfry.com/assets/w38-search-web.svg" width="14"/></button><!-- --><!-- --></div></div><!-- --></div><div _ngcontent-sc169="" class="hd-logo-wrap"><a _ngcontent-sc169="" class="pf-logo" data-test="pepperfryLogo" href="/"><img _ngcontent-sc169="" alt="PepperfryLogo" height="47" src="https://ii1.pepperfry.com/assets/w38-pf-logo-desktop.svg" width="219"/></a><!-- --><!-- --></div><div _ngcontent-sc169="" class="header-icons"><pf-header-icons _ngcontent-sc169="" _nghost-sc166=""><div _ngcontent-sc166="" class="hd-icon-wrapper"><div _ngcontent-sc166="" class="hd-profile-wrap hd-menu-level-top" hover-class="active"><div _ngcontent-sc166="" class="wrap-text-icon"><div _ngcontent-sc166="" class="user-credit-text cursor-pointer"><div _ngcontent-sc166="" class="sign-up-text text-xs font-semibold text-right">S ...
# <div class="row">
# <div class="pf-col md-8 sm-12 seo-content-left">
# <div class="row">
# <div class="pf-col md-12 sm-12"><img class="hide-mobile" src="https://ii1.pepperfry.com/media/wysiwyg/banners/vip_seo_01_furniture.png"/>
# <p class="vip-ftrcnt-ttl"><span>Explore More From</span> Furniture</p>
# </div>
# </div>
# <div class="row">
# <div class="pf-col md-12 sm-12">
# <div class="row">
# <div class="pf-col md-3 sm-3 vip-ftr-column">
# <ul>
# <li><a href="https://www.pepperfry.com/category/sofas.html?type=vip-explore-more">Sofas</a></li>
# <li><a href="https://www.pepperfry.com/category/3-seater-sofas.html?type=vip-explore-more">3 Seater Sofas</a></li>
# <li><a href="https://www.pepperfry.com/category/sofa-sets.html?type=vip-explore-more">Sofa Sets</a></li>
# <li><a href="https://www.pepperfry.com/category/sectional-sofas.html?type=vip-explore-more">Sectional Sofas</a></li>
# <li><a href="https://www.pepperfry.com/category/sofa-cum-beds.html?type=vip-explore-more">Sofa Cum Beds</a></li>
# <li><a href="https://www.pepperfry.com/category/recliners.html?type=vip-explore-more">Recliners</a></li>
# <li><a href="https://www.pepperfry.com/category/wing-chairs.html?type=vip-explore-more">Wing Chairs</a></li>
# <li><a href="https://www.pepperfry.com/category/lounge-chairs.html?type=vip-explore-more">Lounge Chairs</a></li>
# <li><a href="https://www.pepperfry.com/category/chairs.html?type=vip-explore-more">Chairs</a></li>
# </ul>
# </div>
# <div class="pf-col md-3 sm-3 vip-ftr-column">
# <ul>
# <li><a href="https://www.pepperfry.com/category/gaming-chairs.html?type=vip-explore-more">Gaming Chairs</a></li>
# <li><a href="https://www.pepperfry.com/category/shoe-racks.html?type=vip-explore-more">Shoe Racks</a></li>
# <li><a href="https://www.pepperfry.com/category/centre-tables.html?type=vip-explore-more">Centre Tables</a></li>
# <li><a href="https://www.pepperfry.com/category/side-tables.html?type=vip-explore-more">Side Tables</a></li>
# <li><a href="https://www.pepperfry.com/category/tv-units.html?type=vip-explore-more">TV Units</a></li>
# <li><a href="https://www.pepperfry.com/category/crockery-units.html?type=vip-explore-more">Crockery Units</a></li>
# <li><a href="https://www.pepperfry.com/category/dressing-tables.html?type=vip-explore-more">Dressing Tables</a></li>
# <li><a href="https://www.pepperfry.com/category/dressing-units.html?type=vip-explore-more">Dressing Units</a></li>
# <li><a href="https://www.pepperfry.com/category/study-tables.html?type=vip-explore-more">Study Tables</a></li>
# </ul>
# </div>
# <div class="pf-col md-3 sm-3 hide-mobile">
# <ul>
# <li><a href="https://www.pepperfry.com/category/dining-sets.html?type=vip-explore-more">Dining Sets</a></li>
# <li><a href="https://www.pepperfry.com/discover/fabric-sofas.html?type=vip-explore-more">Fabric Sofas</a></li>
# <li><a href="https://www.pepperfry.com/discover/velvet-sofas.html?type=vip-explore-more">Velvet Sofas</a></li>
# <li><a href="https://www.pepperfry.com/discover/wooden-sofa-sets.html?type=vip-explore-more">Wooden Sofa Sets</a></li>
# <li><a href="https://www.pepperfry.com/discover/storage-beds.html?type=vip-explore-more">Storage Beds</a></li>
# <li><a href="https://www.pepperfry.com/discover/leather-sofa-sets.html?type=vip-explore-more">Leather Sofa Sets</a></li>
# <li><a href="https://www.pepperfry.com/discover/living-room-furniture.html?type=vip-explore-more">Living Room Furniture</a></li>
# <li><a href="https://www.pepperfry.com/discover/double-beds.html?type=vip-explore-more">Double Beds</a></li>
# <li><a href="https://www.pepperfry.com/discover/hydraulic-beds.html?type=vip-explore-more">Hydraulic Beds</a></li>
# </ul>
# </div>
# <div class="pf-col md-3 sm-3 hide-mobile">
# <ul>
# <li><a href="https://www.pepperfry.com/discover/box-beds.html?type=vip-explore-more">Box Beds</a></li>
# <li><a href="https://www.pepperfry.com/discover/bedroom-furniture.html?type=vip-explore-more">Bedroom Furniture</a></li>
# <li><a href="https://www.pepperfry.com/discover/mirror-wardrobes.html?type=vip-explore-more">Mirror Wardrobes</a></li>
# <li><a href="https://www.pepperfry.com/discover/wooden-furnitures.html?type=vip-explore-more">Wooden Furnitures</a></li>
# <li><a href="https://www.pepperfry.com/discover/rattan-furnitures.html?type=vip-explore-more">Rattan Furniture</a></li>
# <li><a href="https://www.pepperfry.com/discover/fabric-sofa-sets.html?type=vip-explore-more">Fabric Sofa Sets</a></li>
# <li><a href="https://www.pepperfry.com/discover/leather-chairs.html?type=vip-explore-more">Leather Chairs</a></li>
# <li><a href="https://www.pepperfry.com/category/dining-tables.html?type=vip-explore-more">Dining Tables</a></li>
# <li><a href="https://www.pepperfry.com/discover/dining-room-furnitures.html?type=vip-explore-more">Dining Room Furniture</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="pf-col md-4 sm-12 seo-content-right hide-mobile">
# <div class="row">
# <div class="pf-col md-12 sm-12"><img src="https://ii2.pepperfry.com/images/vip-seo_2.png"/>
# <p class="pf-padding-left-10">FROM POPULAR BRANDS</p>
# </div>
# </div>
# <div class="row pf-padding-left-10">
# <div class="pf-col md-6 sm-6">
# <ul>
# <li><a href="https://www.pepperfry.com/brands/woodsworth.html?type=hp-footer-link-brands-2type=vip-explore-more">Woodsworth</a></li>
# <li><a href="https://www.pepperfry.com/brands/mintwud.html?type=hp-footer-link-brands-1type=vip-explore-more">Mintwud</a></li>
# <li><a href="https://www.pepperfry.com/brands/bohemiana.html?type=hp-footer-link-brands-6type=vip-explore-more">Bohemiana</a></li>
# <li><a href="https://www.pepperfry.com/brands/mudramark.html?type=hp-footer-link-brands-5type=vip-explore-more">Mudramark</a></li>
# <li><a href="https://www.pepperfry.com/brands/crystal-furnitech.html?cat_id=1505&amp;requestPlatform=web&amp;sort_field=sorting_score&amp;sort_by=desc&amp;brandsname=Crystal%20Furnitech&amp;sort_name=Relevance&amp;page=1type=vip-explore-more">Crystal Furnitech</a></li>
# <li><a href="https://www.pepperfry.com/brands/durian.html?cat_id=1505&amp;requestPlatform=web&amp;sort_field=sorting_score&amp;sort_by=desc&amp;brandsname=Durian&amp;sort_name=Relevance&amp;page=1type=vip-explore-more">Durian</a></li>
# <li><a href="https://www.pepperfry.com/brands/hometown.html?cat_id=1505&amp;requestPlatform=web&amp;sort_field=sorting_score&amp;sort_by=desc&amp;brandsname=HomeTown&amp;sort_name=Relevance&amp;page=1type=vip-explore-more">HomeTown</a></li>
# <li><a href="https://www.pepperfry.com/brands/nilkamal.html?cat_id=1505&amp;requestPlatform=web&amp;sort_field=sorting_score&amp;sort_by=desc&amp;brandsname=Nilkamal&amp;sort_name=Relevance&amp;page=1type=vip-explore-more">Nilkamal</a></li>
# </ul>
# </div>
# <div class="pf-col md-6 sm-6"></div>
# </div>
# </div>
# </div>
# </div></div><!-- --><!-- --></pf-vip-seo-footer></section></div><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --></app-vip><!-- --></main><pf-footer _ngcontent-sc181="" _nghost-sc160=""><div _ngcontent-sc160="" class="footer-container"><div _ngcontent-sc160="" class="footer-wrapper"><pf-footer-page _ngcontent-sc160="" _nghost-sc158=""><footer _ngcontent-sc158=""><div _ngcontent-sc158="" class="footer-wrapper footer-margin-bottom"><div _ngcontent-sc158="" class="container"><div _ngcontent-sc158="" class="first-row-section"><div _ngcontent-sc158="" class="row paddingTop-42"><div _ngcontent-sc158="" class="footer-col"><p _ngcontent-sc158="" class="text-lg font-extrabold corporate">Corporate</p><ul _ngcontent-sc158="" class="ul-flex" data-test="corporate-section"><li _ngcontent-sc158="" class="text-md color-secondary marginBottom-8 cursor-pointer"><a _ngcontent-sc158="" data-test="categorySectionMb-0">About Us</a></li><li _ngcontent-sc158="" class="text-md color-secondary marginBottom-8 cursor-pointer"><a _ngcontent-sc158="" data-test="categorySectionMb-1">Corporate Governance</a></li><li _ngcontent-sc158="" class="text-md color-secondary marginBottom-8 cursor-pointer"><a _ngcontent-sc158="" data-test="categorySectionMb-2">Pepperfry in the News</a></li><li _ngcontent-sc158="" class="text-md color-secondary marginBottom-8 cursor-pointer"><a _ngcontent-sc158="" data-test="categorySectionMb-3">Careers</a></li><!-- --></ul></div><div _ngcontent-sc158="" class="footer-col"><p _ngcontent-sc158="" class="text-lg font-extrabold usefulLinks"> Useful Links</p><ul _ngcontent-sc158="" class="ul-flex" data-test="usefulLinks-section"><li _ngcontent-sc158="" class="text-md color-secondary marginBottom-8 cursor-pointer"><a _ngcontent-sc158="" data-test="categorySectionDesk-0">Explore Gift Cards</a></li><li _ngcontent-sc158="" class="text-md color-secondary marginBottom-8 cursor-pointer"><a _ngcontent-sc158="" data-test="categorySectionDesk-1">Buy in Bulk</a></li><li _ngcontent-sc158="" class="text-md color-secondary marginBottom-8 cursor-pointer"><a _ngcontent-sc158="" data-test="categorySectionDesk-2">Discover Our Brands</a></li><li _ngcontent-sc158="" class="text-md color-secondary marginBottom-8 cursor-pointer"><a _ngcontent-sc158="" data-test="categorySectionDesk-3">Check Out Bonhomie, Our Blog</a></li><li _ngcontent-sc158="" class="text-md color-secondary marginBottom-8 cursor-pointer"><a _ngcontent-sc158="" data-test="categorySectionDesk-4">Find a Store</a></li><!-- --></ul></div><div _ngcontent-sc158="" class="footer-col"><p _ngcontent-sc158="" class="text-lg font-extrabold partnerwithus">Partner With Us</p><ul _ngcontent-sc158="" class="ul-flex" data-test="partnerwith-us-section"><li _ngcontent-sc158="" class="text-md color-secondary marginBottom-8 cursor-pointer"><a _ngcontent-sc158="" data-test="patternSectionDesk-0">Sell on Pepperfry</a></li><li _ngcontent-sc158="" class="text-md color-secondary marginBottom-8 cursor-pointer"><a _ngcontent-sc158="" data-test="patternSectionDesk-1">Become a Franchisee</a></li><li _ngcontent-sc158="" class="text-md color-secondary marginBottom-8 cursor-pointer"><a _ngcontent-sc158="" data-test="patternSectionDesk-2">Become Our Channel Partner</a></li><li _ngcontent-sc158="" class="text-md color-secondary marginBottom-8 cursor-pointer"><a _ngcontent-sc158="" data-test="patternSectionDesk-3">Become Our Pep Homie</a></li><li _ngcontent-sc158="" class="text-md color-secondary marginBottom-8 cursor-pointer"><a _ngcontent-sc158="" data-test="patternSectionDesk-4">Our Marketplace Policies</a></li><li _ngcontent-sc158="" class="text-md color-secondary marginBottom-8 cursor-pointer"><a _ngcontent-sc158="" data-test="patternSectionDesk-5">Merchant Dashboard Login</a></li><!-- --></ul></div><div _ngcontent-sc158="" class="footer-col"><p _ngcontent-sc158="" class="text-lg font-extrabold needhelp">Need Help?</p><ul _ngcontent-sc158="" class="ul-flex" data-test="need-help-section"><li _ngcontent ...
# <script fetchpriority="high" src="runtime.29ce6eabdc558575.js" type="module"></script><script fetchpriority="high" src="polyfills.ce4a028b01835e3d.js" type="module"></script><script fetchpriority="high" src="vendor.f484dac730b46ff5.js" type="module"></script><script fetchpriority="high" src="main.a0a1c3a979f90338.js" type="module"></script>
# <noscript async="true"><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-TWGMR3" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <noscript async="true">
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-K8V3Z8" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <noscript defer=""><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-N92Z4HX" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <noscript defer=""><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-T5D99ZQ" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <noscript>
# <img src="www.pepperfry.com/logger/noscript"/>
# </noscript>
# <!-- <script defer>
#   if (window.innerWidth <= 720) {
#   !function(t,e,n,s,a,c,i,o,p){t.AppsFlyerSdkObject=a,t.AF=t.AF||function(){(t.AF.q=t.AF.q||[]).push([Date.now()].concat(Array.prototype.slice.call(arguments)))},t.AF.id=t.AF.id||i,t.AF.plugins={},o=e.createElement(n),p=e.getElementsByTagName(n)[0],o.defer=1,o.src="https://websdk.appsflyer.com?"+(c.length>0?"st="+c.split(",").sort().join(",")+"&":"")+(i.length>0?"af_id="+i:""),p.parentNode.insertBefore(o,p)}(window,document,"script",0,"AF","banners",{banners: {key: "5504562d-c8c0-4d00-b144-abec5282bb44"}})
#   AF('banners', 'showBanner')
#   }
#   </script> -->
# <script defer="">
#
#   if (window.innerWidth <= 720) {
#     (function (w, d, s, l, i) {
#       w[l] = w[l] || []; w[l].push({
#         'gtm.start': new Date().getTime(),
#         event: 'gtm.js'
#       });
#       var f = d.getElementsByTagName(s)[0],
#         j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.defer = true;
#       j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#     })(window, document, 'script', 'dataLayer', 'GTM-N92Z4HX');
#   } else {
#     (function (w, d, s, l, i) {
#       w[l] = w[l] || []; w[l].push({
#         'gtm.start': new Date().getTime(),
#         event: 'gtm.js'
#       });
#       var f = d.getElementsByTagName(s)[0],
#         j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.defer = true;
#       j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#     })(window, document, 'script', 'dataLayer', 'GTM-T5D99ZQ');
#   }
# </script>
# <!-- <script type="text/javascript" defer crossorigin >
#   window._mfq = window._mfq || [];
#   (function () {
#     var mf = document.createElement("script");
#     mf.type = "text/javascript"; mf.defer = true;
#     mf.src = "//cdn.mouseflow.com/projects/5b682ad1-e019-4731-80c4-d3703b7fd36d.js";
#     document.getElementsByTagName("head")[0].appendChild(mf);
#   })();
# </script> -->
# <script id="serverApp-state" type="application/json">{&q;G.json.https://www.pepperfry.com/homeapp-api/static-block/ef976b07-ab9d-438f-96c2-f5ccf002edf5?&q;:{&q;body&q;:{&q;status&q;:200,&q;data&q;:{&q;additiondata&q;:&q;additiondata test&q;,&q;id&q;:&q;ef976b07-ab9d-438f-96c2-f5ccf002edf5&q;,&q;title&q;:&q;test1&q;,&q;identifier&q;:&q;footer&q;,&q;contentHTML&q;:&q;html&q;,&q;contentJSON&q;:{&q;app_url&q;:&q;&q;,&q;cities_section&q;:{&q;list&q;:[{&q;name&q;:&q;Bengaluru&q;,&q;redirect_url&q;:&q;#&q;},{&q;name&q;:&q;Mumbai&q;,&q;redirect_url&q;:&q;#&q;},{&q;name&q;:&q;Navi Mumbai&q;,&q;redirect_url&q;:&q;#&q;},{&q;name&q;:&q;Delhi&q;,&q;redirect_url&q;:&q;#&q;},{&q;name&q;:&q;Hyderabad&q;,&q;redirect_url&q;:&q;#&q;},{&q;name&q;:&q;Pune&q;,&q;redirect_url&q;:&q;#&q;},{&q;name&q;:&q;Chennai&q;,&q;redirect_url&q;:&q;#&q;},{&q;name&q;:&q;Gurgaon&q;,&q;redirect_url&q;:&q;#&q;},{&q;name&q;:&q;Kolkata&q;,&q;redirect_url&q;:&q;#&q;},{&q;name&q;:&q;Noida&q;,&q;redirect_url&q;:&q;#&q;},{&q;name&q;:&q;Goa&q;,&q;redirect_url&q;:&q;#&q;},{&q;name&q;:&q;Ghaziabad&q;,&q;redirect_url&q;:&q;#&q;},{&q;name&q;:&q;Faridabad&q;,&q;redirect_url&q;:&q;#&q;},{&q;name&q;:&q;Jaipur&q;,&q;redirect_url&q;:&q;#&q;},{&q;name&q;:&q;Lucknow&q;,&q;redirect_url&q;:&q;#&q;},{&q;name&q;:&q;Kochi&q;,&q;redirect_url&q;:&q;#&q;},{&q;name&q;:&q;Visakhapatnam&q;,&q;redirect_url&q;:&q;#&q;},{&q;name&q;:&q;Chandigarh&q;,&q;redirect_url&q;:&q;#&q;},{&q;name&q;:&q;Vadodara&q;,&q;redirect_url&q;:&q;#&q;},{&q;name&q;:&q;Nagpur&q;,&q;redirect_url&q;:&q;#&q;},{&q;name&q;:&q;Thiruvananthapuram&q;,&q;redirect_url&q;:&q;#&q;},{&q;name&q;:&q;Indore&q;,&q;redirect_url&q;:&q;#&q;},{&q;name&q;:&q;Mysore&q;,&q;redirect_url&q;:&q;#&q;},{&q;name&q;:&q;Bhopal&q;,&q;redirect_url&q;:&q;#&q;},{&q;name&q;:&q;Surat&q;,&q;redirect_url&q;:&q;#&q;},{&q;name&q;:&q;Jalandhar&q;,&q;redirect_url&q;:&q;#&q;},{&q;name&q;:&q;Patna&q;,&q;redirect_url&q;:&q;#&q;},{&q;name&q;:&q;Ludhiana&q;,&q;redirect_url&q;:&q;#&q;},{&q;name&q;:&q;Ahmedabad&q;,&q;redirect_url&q;:&q;#&q;},{&q;name&q;:&q;Nashik&q;,&q;redirect_url&q;:&q;#&q;},{&q;name&q;:&q;Madurai&q;,&q;redirect_url&q;:&q;#&q;},{&q;name&q;:&q;Kanpur&q;,&q;redirect_url&q;:&q;#&q;},{&q;name&q;:&q;Aurangabad&q;,&q;redirect_url&q;:&q;#&q;}],&q;title&q;:&q;Popular cities &q;},&q;partners_section&q;:{&q;list&q;:[{&q;name&q;:&q;Sell on Pepperfry&q;,&q;redirect_url&q;:&q;https://www.pepperfry.com/form/partners-partnerwithus.html&q;},{&q;name&q;:&q;Become a Franchisee&q;,&q;redirect_url&q;:&q;https://www.pepperfry.com/form/partners-franchisee.html&q;},{&q;name&q;:&q;Become Our Channel Partner&q;,&q;redirect_url&q;:&q;https://www.pepperfry.com/form/partners-channelpartner.html&q;},{&q;name&q;:&q;Become Our Pep Homie&q;,&q;redirect_url&q;:&q;https://www.pepperfry.com/form/partners-pephomie.html&q;},{&q;name&q;:&q;Our Marketplace Policies&q;,&q;redirect_url&q;:&q;https://www.pepperfry.com/tnc/marketplace_policies.html&q;},{&q;name&q;:&q;Merchant Dashboard Login&q;,&q;redirect_url&q;:&q;https://seller.pepperfry.com/merchant/login&q;}],&q;title&q;:&q;Partner With Us&q;},&q;corporate_section&q;:{&q;list&q;:[{&q;name&q;:&q;About Us&q;,&q;redirect_url&q;:&q;https://www.pepperfry.ltd/&q;},{&q;name&q;:&q;Corporate Governance&q;,&q;redirect_url&q;:&q;https://www.pepperfry.ltd/investor-relations/&q;},{&q;name&q;:&q;Pepperfry in the News&q;,&q;redirect_url&q;:&q;https://www.pepperfry.ltd/&q;},{&q;name&q;:&q;Careers&q;,&q;redirect_url&q;:&q;https://www.pepperfry.com/pages/careers.html?type=footer&q;}],&q;title&q;:&q;Corporate&q;},&q;need_help_section&q;:{&q;list&q;:[{&q;name&q;:&q;FAQs&q;,&q;redirect_url&q;:&q;https://www.pepperfry.com/customer/needhelp/faq&q;},{&q;name&q;:&q;Policies&q;,&q;redirect_url&q;:&q;https://www.pepperfry.com/customer/needhelp/policies&q;},{&q;name&q;:&q;Contact Us&q;,&q;redirect_url&q;:&q;https://www.pepperfry.com/customer/needhelp/contactus&q;}],&q;title&q;:&q;Need Help?&q;},&q;brand_propositions&q;:{&q;list&q;:[{&q;name&q;:&q;Kids &a; Pet Friendly& ...

# %%
# soup.text

# %%
# scrappy codes for  images

# import scrapy
# url='https://www.pepperfry.com/product/cove-solid-wood-sideboard-in-irish-walnut-colour-2163467.html'
# scrapy shell https://www.pepperfry.com/product/cove-solid-wood-sideboard-in-irish-walnut-colour-2163467.html
# images=response.css('img').getall()[8:17]
# for i in images:
#     start=i.find('src')
#     start+=5
#     end=i.find('jpg')
#     end+=3
#     link=i[start:end]
#     link=link.replace('90x99','1100x1210')

# %%
# product details
# link=url
# product_name=response.css('h1::text').get()
# price=response.css('span::text').getall()[13]

# %%
specs=soup.find_all('h1')

# %%
specs
# Out:
# [<h1 _ngcontent-sc205="" class="color-tertiary text-lg font-medium">Ashoka Sheesham Wood 2 Door Book Case in Brown Colour,</h1>]
